# %%
import pandas as pd
from load_dataset import load_data
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB, CategoricalNB
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, f1_score, recall_score, precision_score, roc_auc_score

from IPython import display

# %%
#dataset original
loader = load_data()
df_original, cat_feat_original = loader.get_original_dataframe()
print(cat_feat_original)
df_original
# Out:
# ['État civil', "Mode d'application", 'Cours', 'Présence jour/soir', 'Qualification antérieure', 'Nationalité', 'Qualification mère', 'Qualification père', 'Occupation mère', 'Occupation père', 'Déplacé', 'Besoins éducatifs spéciaux', 'Dettes', 'Frais de scolarité à jour', 'Sexe', 'Bourse', 'International']
#      État civil Mode d'application  Ordre d'application Cours  \
# 0             1                  8                    5     2
# 1             1                  6                    1    11
# 2             1                  1                    5     5
# 3             1                  8                    2    15
# 4             2                 12                    1     3
# ...         ...                ...                  ...   ...
# 3625          1                  1                    6    15
# 3626          1                  1                    2    15
# 3627          1                  1                    1    12
# 3628          1                  1                    1     9
# 3629          1                  5                    1    15
#
#      Présence jour/soir Qualification antérieure Nationalité  \
# 0                     1                        1           1
# 1                     1                        1           1
# 2                     1                        1           1
# 3                     1                        1           1
# 4                     0                        1           1
# ...                 ...                      ...         ...
# 3625                  1                        1           1
# 3626                  1                        1          19
# 3627                  1                        1           1
# 3628                  1                        1           1
# 3629                  1                        1           9
#
#      Qualification mère Qualification père Occupation mère  ...  \
# 0                    13                 10               6  ...
# 1                     1                  3               4  ...
# 2                    22                 27              10  ...
# 3                    23                 27               6  ...
# 4                    22                 28              10  ...
# ...                 ...                ...             ...  ...
# 3625                  1                  1               6  ...
# 3626                  1                  1              10  ...
# 3627                 22                 27              10  ...
# 3628                 22                 27               8  ...
# 3629                 23                 27               6  ...
#
#      Unités curriculaires 2e semestre (créditées)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 3625                                            0
# 3626                                            0
# 3627                                            0
# 3628                                            0
# 3629                                            0
#
#      Unités curriculaires 2e semestre (inscrits)  \
# 0                                              0
# 1                                              6
# 2                                              6
# 3                                              6
# 4                                              6
# ...                                          ...
# 3625                                           6
# 3626                                           6
# 3627                                           8
# 3628                                           5
# 3629                                           6
#
#      Unités curriculaires 2e semestre (évaluations)  \
# 0                                                 0
# 1                                                 6
# 2                                                 0
# 3                                                10
# 4                                                 6
# ...                                             ...
# 3625                                              8
# 3626                                              6
# 3627                                              9
# 3628                                              6
# 3629                                              6
#
#      Unités curriculaires 2e semestre (approuvées)  \
# 0                                                0
# 1                                                6
# 2                                                0
# 3                                                5
# 4                                                6
# ...                                            ...
# 3625                                             5
# 3626                                             2
# 3627                                             1
# 3628                                             5
# 3629                                             6
#
#      Unités curriculaires 2e semestre (note)  \
# 0                                   0.000000
# 1                                  13.666667
# 2                                   0.000000
# 3                                  12.400000
# 4                                  13.000000
# ...                                      ...
# 3625                               12.666667
# 3626                               11.000000
# 3627                               13.500000
# 3628                               12.000000
# 3629                               13.000000
#
#      Unités curriculaires 2e semestre (sans évaluations) Taux de chômage  \
# 0                                                     0             10.8
# 1                                                     0             13.9
# 2                                                     0             10.8
# 3                                                     0              9.4
# 4                                                     0             13.9
# ...                                                 ...              ...
# 3625                                                  0             15.5
# 3626                                                  0             11.1
# 3627                                                  0             13.9
# 3628                                                  0              9.4
# 3629                                                  0             12.7
#
#       Taux d'inflation   PIB  Cible
# 0                  1.4  1.74      0
# 1                 -0.3  0.79      1
# 2                  1.4  1.74      0
# 3                 -0.8 -3.12      1
# 4                 -0.3  0.79      1
# ...                ...   ...    ...
# 3625               2.8 -4.06      1
# 3626               0.6  2.02      0
# 3627              -0.3  0.79      0
# 3628              -0.8 -3.12      1
# 3629               3.7 -1.70      1
#
# [3630 rows x 35 columns]

# %%
#dataset simplifié
df_simplified, cat_feat_simplified = loader.get_simplify_dataframe()
print(cat_feat_simplified)
df_simplified
# Out:
# ['État civil', "Mode d'application", 'Cours', 'Présence jour/soir', 'Qualification antérieure', 'Qualification mère', 'Qualification père', 'Occupation mère', 'Occupation père', 'Déplacé', 'Besoins éducatifs spéciaux', 'Dettes', 'Frais de scolarité à jour', 'Sexe', 'Bourse', 'International']
#      État civil Mode d'application  Ordre d'application Cours  \
# 0             1                  2                    5     2
# 1             1                 10                    1    10
# 2             1                  1                    5     4
# 3             1                  2                    2    14
# 4             2                 11                    1     9
# ...         ...                ...                  ...   ...
# 3625          1                  1                    6    14
# 3626          1                  1                    2    14
# 3627          1                  1                    1    11
# 3628          1                  1                    1     8
# 3629          1                  9                    1    14
#
#      Présence jour/soir Qualification antérieure Qualification mère  \
# 0                     1                        7                  7
# 1                     1                        7                  8
# 2                     1                        7                  7
# 3                     1                        7                  7
# 4                     0                        7                  7
# ...                 ...                      ...                ...
# 3625                  1                        7                  8
# 3626                  1                        7                  8
# 3627                  1                        7                  7
# 3628                  1                        7                  7
# 3629                  1                        7                  7
#
#      Qualification père Occupation mère Occupation père  ...  \
# 0                    10               6              10  ...
# 1                     4               4               4  ...
# 2                    10              10              10  ...
# 3                    10               6               4  ...
# 4                    10              10              10  ...
# ...                 ...             ...             ...  ...
# 3625                  8               6               5  ...
# 3626                  8              10              10  ...
# 3627                 10              10              10  ...
# 3628                 10               8               5  ...
# 3629                 10               6              10  ...
#
#      Unités curriculaires 2e semestre (créditées)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 3625                                            0
# 3626                                            0
# 3627                                            0
# 3628                                            0
# 3629                                            0
#
#      Unités curriculaires 2e semestre (inscrits)  \
# 0                                              0
# 1                                              6
# 2                                              6
# 3                                              6
# 4                                              6
# ...                                          ...
# 3625                                           6
# 3626                                           6
# 3627                                           8
# 3628                                           5
# 3629                                           6
#
#      Unités curriculaires 2e semestre (évaluations)  \
# 0                                                 0
# 1                                                 6
# 2                                                 0
# 3                                                10
# 4                                                 6
# ...                                             ...
# 3625                                              8
# 3626                                              6
# 3627                                              9
# 3628                                              6
# 3629                                              6
#
#      Unités curriculaires 2e semestre (approuvées)  \
# 0                                                0
# 1                                                6
# 2                                                0
# 3                                                5
# 4                                                6
# ...                                            ...
# 3625                                             5
# 3626                                             2
# 3627                                             1
# 3628                                             5
# 3629                                             6
#
#      Unités curriculaires 2e semestre (note)  \
# 0                                   0.000000
# 1                                  13.666667
# 2                                   0.000000
# 3                                  12.400000
# 4                                  13.000000
# ...                                      ...
# 3625                               12.666667
# 3626                               11.000000
# 3627                               13.500000
# 3628                               12.000000
# 3629                               13.000000
#
#      Unités curriculaires 2e semestre (sans évaluations)  Taux de chômage  \
# 0                                                     0              10.8
# 1                                                     0              13.9
# 2                                                     0              10.8
# 3                                                     0               9.4
# 4                                                     0              13.9
# ...                                                 ...               ...
# 3625                                                  0              15.5
# 3626                                                  0              11.1
# 3627                                                  0              13.9
# 3628                                                  0               9.4
# 3629                                                  0              12.7
#
#      Taux d'inflation   PIB  Cible
# 0                 1.4  1.74      0
# 1                -0.3  0.79      1
# 2                 1.4  1.74      0
# 3                -0.8 -3.12      1
# 4                -0.3  0.79      1
# ...               ...   ...    ...
# 3625              2.8 -4.06      1
# 3626              0.6  2.02      0
# 3627             -0.3  0.79      0
# 3628             -0.8 -3.12      1
# 3629              3.7 -1.70      1
#
# [3630 rows x 34 columns]

# %% [markdown]
# # DecisionTree - RandomForest - NaiveBayes - LogisiticRegression
# ## dataset:
# ### -original + OneHot=False
# ### -original + OneHot=True
# ### -simplified + OneHot=False
# ### -simplified + OneHot=True

# %%
#optimisation des hp
def optimize_hyperparameters(clf, param_grid, X_train, y_train):
    grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, n_jobs=-1, scoring='f1')   #on utilise f1 et cv 5
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, grid_search.best_params_

#calcul des metriques
def calculate_metrics(model, X_test, y_test):
    y_pred = model.predict(X_test)
    metrics = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred),    # sans average='binary'
        "Rappel (recall)": recall_score(y_test, y_pred),   # sans average='binary'
        "Precision": precision_score(y_test, y_pred),    # sans average='binary'
        "ROC-AUC": roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    }
    return metrics


def format_best_params(best_params):
    formatted_params = []
    for param, value in best_params.items():
        formatted_param = f"{param}={value}"
        formatted_params.append(formatted_param)
    return formatted_params





classifiers = {
    "Arbre de decision": DecisionTreeClassifier,
    "Foret aleatoire": RandomForestClassifier,
    "Classificateur naif bayesien": GaussianNB,
    "Régression logistique": LogisticRegression
}

#les plages des hyperparametres de chaque classifieur a tester avec recherche par grille (GridSearchCV)
param_grids = {
    "Arbre de decision": {
        'max_depth': [6, 8, 10, 12, 15],
        'min_samples_split': [50, 100, 190, 200, 210, 225],
        'min_samples_leaf': [15, 20, 25, 30, 40, 60, 100], 
        'criterion': ['gini', 'entropy']},

    "Foret aleatoire": {
        'n_estimators': [100, 300, 600, 1000],
        'max_depth': [7, 10, 15, 20, 25], 
        'max_features':  [None, 'sqrt', 0.2, 0.3, 0.4], 
        'criterion': ['gini', 'entropy']},

    "Classificateur naif bayesien": {
        'var_smoothing': [1e-8, 1e-7, 1e-6, 1e-5],
        'priors': [None, [0.5, 0.5], [0.7, 0.3], [0.3, 0.7]]},

    "Régression logistique": {
        'C': [0.001, 0.01, 0.1, 1, 10, 100],
        'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 
        'max_iter': [10000, 20000]}    
}




best_params_dict = {}
metrics_dict = {}
type_de_dataset = ['simplify', 'original']

for type_data in type_de_dataset:

    for oneHot in [True, False]:

        X, y, cat_features = load_data().get_data_X_y(data=type_data, OneHot=oneHot)
        X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)


        for name, clf_class in classifiers.items():

            if name == "Classificateur naif bayesien":
                clf = clf_class()  # pas de (random_state=42) pour naif bayes
            else:
                clf = clf_class(random_state=42)


            
            best_model, best_params = optimize_hyperparameters(clf, param_grids[name], X_train, y_train)


            #reentrainer les modele avec les best hp
            if name == "Classificateur naif bayesien":
                clf_optimized = best_model  #on peut pas mettre parametre les best hp pour reentrainer CNB, best_model est deja avec les best hp
            else:
                clf_optimized = clf_class(**best_params, random_state=42)

            clf_optimized.fit(X_train, y_train)


            
            metrics = calculate_metrics(clf_optimized, X_test, y_test)

            
            formatted_best_params = format_best_params(best_params)
            best_params_dict[f"{name} ({type_data}, OneHot={oneHot})"] = formatted_best_params
            metrics_dict[f"{name} ({type_data}, OneHot={oneHot})"] = metrics


df_best_params = pd.DataFrame.from_dict(best_params_dict, orient='index')
df_best_params.columns = [f"hp{i+1}" for i in range(df_best_params.shape[1])]
df_best_params_sorted = df_best_params.sort_index()
print("Les meilleurs hyperparametres par classifieur:")
display.display(df_best_params_sorted)

df_metrics = pd.DataFrame.from_dict(metrics_dict, orient='index')
df_metrics['Type de Données'] = [name.split(' ')[-1].split(',')[0] for name in df_metrics.index]
df_metrics['OneHot'] = [name.split('=')[-1] for name in df_metrics.index]
df_metrics_sorted = df_metrics.sort_values(by=['Type de Données', 'OneHot'])
df_metrics_sorted = df_metrics_sorted.drop(columns=['Type de Données', 'OneHot'])
print("\nLes metriques par Classifieur:")
display.display(df_metrics_sorted)
# Out:
# Les meilleurs hyperparametres par classifieur:
#                                                                   hp1  \
# Arbre de decision (original, OneHot=False)          criterion=entropy
# Arbre de decision (original, OneHot=True)              criterion=gini
# Arbre de decision (simplify, OneHot=False)             criterion=gini
# Arbre de decision (simplify, OneHot=True)              criterion=gini
# Classificateur naif bayesien (original, OneHot=...  priors=[0.3, 0.7]
# Classificateur naif bayesien (original, OneHot=...  priors=[0.3, 0.7]
# Classificateur naif bayesien (simplify, OneHot=...  priors=[0.3, 0.7]
# Classificateur naif bayesien (simplify, OneHot=...        priors=None
# Foret aleatoire (original, OneHot=False)               criterion=gini
# Foret aleatoire (original, OneHot=True)             criterion=entropy
# Foret aleatoire (simplify, OneHot=False)               criterion=gini
# Foret aleatoire (simplify, OneHot=True)             criterion=entropy
# Régression logistique (original, OneHot=False)                   C=10
# Régression logistique (original, OneHot=True)                     C=1
# Régression logistique (simplify, OneHot=False)                   C=10
# Régression logistique (simplify, OneHot=True)                     C=1
#
#                                                                     hp2  \
# Arbre de decision (original, OneHot=False)                  max_depth=6
# Arbre de decision (original, OneHot=True)                   max_depth=6
# Arbre de decision (simplify, OneHot=False)                  max_depth=6
# Arbre de decision (simplify, OneHot=True)                   max_depth=6
# Classificateur naif bayesien (original, OneHot=...  var_smoothing=1e-05
# Classificateur naif bayesien (original, OneHot=...  var_smoothing=1e-05
# Classificateur naif bayesien (simplify, OneHot=...  var_smoothing=1e-05
# Classificateur naif bayesien (simplify, OneHot=...  var_smoothing=1e-05
# Foret aleatoire (original, OneHot=False)                   max_depth=15
# Foret aleatoire (original, OneHot=True)                    max_depth=25
# Foret aleatoire (simplify, OneHot=False)                   max_depth=10
# Foret aleatoire (simplify, OneHot=True)                    max_depth=20
# Régression logistique (original, OneHot=False)           max_iter=10000
# Régression logistique (original, OneHot=True)            max_iter=10000
# Régression logistique (simplify, OneHot=False)           max_iter=10000
# Régression logistique (simplify, OneHot=True)            max_iter=10000
#
#                                                                     hp3  \
# Arbre de decision (original, OneHot=False)          min_samples_leaf=15
# Arbre de decision (original, OneHot=True)           min_samples_leaf=15
# Arbre de decision (simplify, OneHot=False)          min_samples_leaf=15
# Arbre de decision (simplify, OneHot=True)           min_samples_leaf=15
# Classificateur naif bayesien (original, OneHot=...                 None
# Classificateur naif bayesien (original, OneHot=...                 None
# Classificateur naif bayesien (simplify, OneHot=...                 None
# Classificateur naif bayesien (simplify, OneHot=...                 None
# Foret aleatoire (original, OneHot=False)               max_features=0.2
# Foret aleatoire (original, OneHot=True)                max_features=0.2
# Foret aleatoire (simplify, OneHot=False)              max_features=sqrt
# Foret aleatoire (simplify, OneHot=True)               max_features=sqrt
# Régression logistique (original, OneHot=False)         solver=newton-cg
# Régression logistique (original, OneHot=True)               solver=saga
# Régression logistique (simplify, OneHot=False)         solver=liblinear
# Régression logistique (simplify, OneHot=True)          solver=liblinear
#
#                                                                      hp4
# Arbre de decision (original, OneHot=False)          min_samples_split=50
# Arbre de decision (original, OneHot=True)           min_samples_split=50
# Arbre de decision (simplify, OneHot=False)          min_samples_split=50
# Arbre de decision (simplify, OneHot=True)           min_samples_split=50
# Classificateur naif bayesien (original, OneHot=...                  None
# Classificateur naif bayesien (original, OneHot=...                  None
# Classificateur naif bayesien (simplify, OneHot=...                  None
# Classificateur naif bayesien (simplify, OneHot=...                  None
# Foret aleatoire (original, OneHot=False)                n_estimators=600
# Foret aleatoire (original, OneHot=True)                n_estimators=1000
# Foret aleatoire (simplify, OneHot=False)                n_estimators=600
# Foret aleatoire (simplify, OneHot=True)                 n_estimators=300
# Régression logistique (original, OneHot=False)                      None
# Régression logistique (original, OneHot=True)                       None
# Régression logistique (simplify, OneHot=False)                      None
# Régression logistique (simplify, OneHot=True)                       None
# Les metriques par Classifieur:
#                                                     Accuracy  F1 Score  \
# Arbre de decision (simplify, OneHot=False)          0.895317  0.918221
# Foret aleatoire (simplify, OneHot=False)            0.909091  0.929537
# Classificateur naif bayesien (simplify, OneHot=...  0.842057  0.876437
# Régression logistique (simplify, OneHot=False)      0.914601  0.932852
# Arbre de decision (original, OneHot=False)          0.899908  0.921752
# Foret aleatoire (original, OneHot=False)            0.905418  0.926376
# Classificateur naif bayesien (original, OneHot=...  0.844812  0.880057
# Régression logistique (original, OneHot=False)      0.917355  0.934877
# Arbre de decision (simplify, OneHot=True)           0.898990  0.921316
# Foret aleatoire (simplify, OneHot=True)             0.908173  0.928469
# Classificateur naif bayesien (simplify, OneHot=...  0.788797  0.831625
# Régression logistique (simplify, OneHot=True)       0.914601  0.932657
# Arbre de decision (original, OneHot=True)           0.898990  0.921316
# Foret aleatoire (original, OneHot=True)             0.904500  0.926031
# Classificateur naif bayesien (original, OneHot=...  0.787879  0.829772
# Régression logistique (original, OneHot=True)       0.915519  0.933526
#
#                                                     Rappel (recall)  \
# Arbre de decision (simplify, OneHot=False)                 0.948148
# Foret aleatoire (simplify, OneHot=False)                   0.967407
# Classificateur naif bayesien (simplify, OneHot=...         0.903704
# Régression logistique (simplify, OneHot=False)             0.957037
# Arbre de decision (original, OneHot=False)                 0.951111
# Foret aleatoire (original, OneHot=False)                   0.960000
# Classificateur naif bayesien (original, OneHot=...         0.918519
# Régression logistique (original, OneHot=False)             0.957037
# Arbre de decision (simplify, OneHot=True)                  0.954074
# Foret aleatoire (simplify, OneHot=True)                    0.961481
# Classificateur naif bayesien (simplify, OneHot=...         0.841481
# Régression logistique (simplify, OneHot=True)              0.954074
# Arbre de decision (original, OneHot=True)                  0.954074
# Foret aleatoire (original, OneHot=True)                    0.964444
# Classificateur naif bayesien (original, OneHot=...         0.834074
# Régression logistique (original, OneHot=True)              0.957037
#
#                                                     Precision   ROC-AUC
# Arbre de decision (simplify, OneHot=False)           0.890125  0.928726
# Foret aleatoire (simplify, OneHot=False)             0.894521  0.952013
# Classificateur naif bayesien (simplify, OneHot=...   0.850767  0.890862
# Régression logistique (simplify, OneHot=False)       0.909859  0.954811
# Arbre de decision (original, OneHot=False)           0.894150  0.924772
# Foret aleatoire (original, OneHot=False)             0.895028  0.951934
# Classificateur naif bayesien (original, OneHot=...   0.844687  0.893163
# Régression logistique (original, OneHot=False)       0.913720  0.956894
# Arbre de decision (simplify, OneHot=True)            0.890733  0.928007
# Foret aleatoire (simplify, OneHot=True)              0.897649  0.952755
# Classificateur naif bayesien (simplify, OneHot=...   0.821997  0.844210
# Régression logistique (simplify, OneHot=True)        0.912181  0.955230
# Arbre de decision (original, OneHot=True)            0.890733  0.925810
# Foret aleatoire (original, OneHot=True)              0.890561  0.953727
# Classificateur naif bayesien (original, OneHot=...   0.825513  0.826937
# Régression logistique (original, OneHot=True)        0.911142  0.954568
