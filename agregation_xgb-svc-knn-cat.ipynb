# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn import metrics
from sklearn.metrics import classification_report, f1_score
from catboost import CatBoostClassifier

from load_dataset import load_data

# %%
# load drive in Colab environment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Utils functions and global variables

# %%
# unused here but provides a non-optimized ready to use dataset
def load_data_nonOptimized():
  data = pd.read_csv("drive/MyDrive/data_ml_project_GIF4101/dataset.csv")

  # remove "Enrolled" target as it's not relevant to the project
  data = data[data['Target'] != "Enrolled"]

  # separating X from Y
  dataY = data.iloc[:,-1:]
  dataX = data.drop("Target", axis=1)

  # numpyification
  arrayX = pd.DataFrame.to_numpy(dataX)
  arrayY = pd.DataFrame.to_numpy(dataY)

  X_train, X_test, y_train, y_test = train_test_split(arrayX, arrayY, test_size=0.2, random_state=42)

  # transforming target labels to either 1 or 0
  le = LabelEncoder()
  y_train = le.fit_transform(y_train)
  y_test = le.fit_transform(y_test)

  return X_train, X_test, y_train, y_test

# %%
def get_max_from_dict(dict):
  max_value = 0
  for key, val in dict.items():
    if val > max_value:
      max_key = key
      max_value = val

  return (max_key, max_value)

# %%
dict_accuracy = {}
dict_f1 = {}

# %% [markdown]
# # Instancier jeux de données

# %% [markdown]
# Depuis la classe utilitaire load_dataset, instancier différentes versions du jeux de données. Les modèles seront testés sur la base des 4 jeux de données, ce qui permettra d'avoir une meilleure visibilité sur la pertinence des modifications de chaque versions en rapport à leurs résultats respectifs.
#
# Cela facilitera aussi la sélection des jeux de données à pousser plus loin en analyse des features.
#
# La variables cat_features_catb est surtout utile pour l'entraînement du CatBoost qui ne peux seulement consommer que la version Simplified du dataset.

# %%
X, y, cat_features = load_data().get_data_X_y(data='simplify', OneHot=True)
X_train_simplified_oneHot, X_test_simplified_oneHot, y_train_simplified_oneHot, y_test_simplified_oneHot = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X, y, cat_features = load_data().get_data_X_y(data='original', OneHot=True)
X_train_original_oneHot, X_test_original_oneHot, y_train_original_oneHot, y_test_original_oneHot = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X, y, cat_features_catb = load_data().get_data_X_y(data='simplify')
X_train_simplified, X_test_simplified, y_train_simplified, y_test_simplified = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X, y, cat_features = load_data().get_data_X_y(data='original')
X_train_original, X_test_original, y_train_original, y_test_original = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # XGboost

# %% [markdown]
# ## Recherche en grille

# %% [markdown]
# Le booster est, ici, nécessairement Gblinear. Les deux autre choix, en l'occurence Gbtree et Dart, prenaient un temps immense à être entrainés dans la recherche en grille. De plus, des tests hors recherche en grille ont prouvés à plusieurs reprises que Gblinear offre des meilleurs résultats d'accuracy et de score f1 sur nos données.
#
# Par mesure de simplicité et d'efficacité, le paramètre booster est donc défini par défaut sur Gblinear et la recherche en grille s'effectue sur la base des paramètres relatifs à un booster de type Gblinear.

# %%
# init xgb classifier
xgb_clf = xgb.XGBClassifier(verbosity=3, random_state=42)

param_grid = {
    'objective':["binary:logistic", "binary:hinge"],
    'booster':["gblinear"],
    'enable_categorical':[True],
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.05, 0.1],
}


# init grid search
grid_search = GridSearchCV(estimator=xgb_clf, param_grid=param_grid, cv=3, scoring='f1')

grid_search.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# [00:11:43] ======== Monitor (0): Learner ========
# [00:11:43] Configure: 0.017187s, 1 calls @ 17187us
#
# [00:11:43] EvalOneIter: 0.000534s, 50 calls @ 534us
#
# [00:11:43] GetGradient: 0.031376s, 50 calls @ 31376us
#
# [00:11:43] PredictRaw: 0.075698s, 50 calls @ 75698us
#
# [00:11:43] UpdateOneIter: 0.208365s, 50 calls @ 208365us
#
# [00:11:43] ======== Monitor (0): GBLinear ========
# [00:11:43] DoBoost: 0.083332s, 50 calls @ 83332us
#
# [00:11:43] PredictBatch: 0.075565s, 50 calls @ 75565us
#
# [00:11:43] PredictBatchInternal: 0.075495s, 50 calls @ 75495us
#
# [00:11:44] ======== Monitor (0): Learner ========
# [00:11:44] Configure: 0.000787s, 1 calls @ 787us
#
# [00:11:44] EvalOneIter: 0.009432s, 50 calls @ 9432us
#
# [00:11:44] GetGradient: 0.00238s, 50 calls @ 2380us
#
# [00:11:44] PredictRaw: 0.066878s, 50 calls @ 66878us
#
# [00:11:44] UpdateOneIter: 0.180126s, 50 calls @ 180126us
#
# [00:11:44] ======== Monitor (0): GBLinear ========
# [00:11:44] DoBoost: 0.109665s, 50 calls @ 109665us
#
# [00:11:44] PredictBatch: 0.066774s, 50 calls @ 66774us
#
# [00:11:44] PredictBatchInternal: 0.066717s, 50 calls @ 66717us
#
# [00:11:44] ======== Monitor (0): Learner ========
# [00:11:44] Configure: 0.000901s, 1 calls @ 901us
#
# [00:11:44] EvalOneIter: 0.00031s, 50 calls @ 310us
#
# [00:11:44] GetGradient: 0.001594s, 50 calls @ 1594us
#
# [00:11:44] PredictRaw: 0.014051s, 50 calls @ 14051us
#
# [00:11:44] UpdateOneIter: 0.068114s, 50 calls @ 68114us
#
# [00:11:44] ======== Monitor (0): GBLinear ========
# [00:11:44] DoBoost: 0.05126s, 50 calls @ 51260us
#
# [00:11:44] PredictBatch: 0.013987s, 50 calls @ 13987us
#
# [00:11:44] PredictBatchInternal: 0.013952s, 50 calls @ 13952us
#
# [00:11:45] ======== Monitor (0): Learner ========
# [00:11:45] Configure: 0.000896s, 1 calls @ 896us
#
# [00:11:45] EvalOneIter: 0.000921s, 50 calls @ 921us
#
# [00:11:45] GetGradient: 0.039066s, 50 calls @ 39066us
#
# [00:11:45] PredictRaw: 0.12641s, 50 calls @ 126410us
#
# [00:11:45] UpdateOneIter: 0.515101s, 50 calls @ 515101us
#
# [00:11:45] ======== Monitor (0): GBLinear ========
# [00:11:45] DoBoost: 0.348253s, 50 calls @ 348253us
#
# [00:11:45] PredictBatch: 0.12628s, 50 calls @ 126280us
#
# [00:11:45] PredictBatchInternal: 0.126192s, 50 calls @ 126192us
#
# [00:11:46] ======== Monitor (0): Learner ========
# [00:11:46] Configure: 0.001021s, 1 calls @ 1021us
#
# [00:11:46] EvalOneIter: 0.000839s, 50 calls @ 839us
#
# [00:11:46] GetGradient: 0.148638s, 50 calls @ 148638us
#
# [00:11:46] PredictRaw: 0.256284s, 50 calls @ 256284us
#
# [00:11:46] UpdateOneIter: 0.951602s, 50 calls @ 951602us
#
# [00:11:46] ======== Monitor (0): GBLinear ========
# [00:11:46] DoBoost: 0.545081s, 50 calls @ 545081us
#
# [00:11:46] PredictBatch: 0.25612s, 50 calls @ 256120us
#
# [00:11:46] PredictBatchInternal: 0.256012s, 50 calls @ 256012us
#
# [00:11:46] ======== Monitor (0): Learner ========
# [00:11:46] Configure: 0.000877s, 1 calls @ 877us
#
# [00:11:46] EvalOneIter: 0.000658s, 50 calls @ 658us
#
# [00:11:46] GetGradient: 0.002835s, 50 calls @ 2835us
#
# [00:11:46] PredictRaw: 0.096874s, 50 calls @ 96874us
#
# [00:11:46] UpdateOneIter: 0.297918s, 50 calls @ 297918us
#
# [00:11:46] ======== Monitor (0): GBLinear ========
# [00:11:46] DoBoost: 0.196853s, 50 calls @ 196853us
#
# [00:11:46] PredictBatch: 0.096741s, 50 calls @ 96741us
#
# [00:11:46] PredictBatchInternal: 0.096653s, 50 calls @ 96653us
#
# [00:11:47] ======== Monitor (0): Learner ========
# [00:11:47] Configure: 0.001111s, 1 calls @ 1111us
#
# [00:11:47] EvalOneIter: 0.001181s, 100 calls @ 1181us
#
# [00:11:47] GetGradient: 0.048679s, 100 calls @ 48679us
#
# [00:11:47] PredictRaw: 0.175035s, 100 calls @ 175035us
#
# [00:11:47] UpdateOneIter: 0.561622s, 100 calls @ 561622us
#
# [00:11:47] ======== Monitor (0): GBLinear ========
# [00:11:47] DoBoost: 0.273297s, 100 calls @ 273297us
#
# [00:11:47] PredictBatch: 0.174842s, 100 calls @ 174842us
#
# [00:11:47] PredictBatchInternal: 0.174669s, 100 calls @ 174669us
#
# [00:11:48] ======== Monitor (0): Learner ========
# [00:11:48] Configure: 0.001061s, 1 calls @ 1061us
#
# [00:11:48] EvalOneIter: 0.001347s, 100 calls @ 1347us
#
# [00:11:48] GetGradient: 0.059604s, 100 calls @ 59604us
#
# [00:11:48] PredictRaw: 0.173319s, 100 calls @ 173319us
#
# [00:11:48] UpdateOneIter: 0.591069s, 100 calls @ 591069us
#
# [00:11:48] ======== Monitor (0): GBLinear ========
# [00:11:48] DoBoost: 0.297083s, 100 calls @ 297083us
#
# [00:11:48] PredictBatch: 0.171449s, 100 calls @ 171449us
#
# [00:11:48] PredictBatchInternal: 0.171319s, 100 calls @ 171319us
#
# [00:11:51] ======== Monitor (0): Learner ========
# [00:11:51] Configure: 0.001023s, 1 calls @ 1023us
#
# [00:11:51] EvalOneIter: 0.001599s, 100 calls @ 1599us
#
# [00:11:51] GetGradient: 0.375333s, 100 calls @ 375333us
#
# [00:11:51] PredictRaw: 0.596615s, 100 calls @ 596615us
#
# [00:11:51] UpdateOneIter: 2.29088s, 100 calls @ 2290885us
#
# [00:11:51] ======== Monitor (0): GBLinear ========
# [00:11:51] DoBoost: 1.25453s, 100 calls @ 1254531us
#
# [00:11:51] PredictBatch: 0.590994s, 100 calls @ 590994us
#
# [00:11:51] PredictBatchInternal: 0.590802s, 100 calls @ 590802us
#
# [00:11:55] ======== Monitor (0): Learner ========
# [00:11:55] Configure: 0.001028s, 1 calls @ 1028us
#
# [00:11:55] EvalOneIter: 0.015186s, 100 calls @ 15186us
#
# [00:11:55] GetGradient: 0.597397s, 100 calls @ 597397us
#
# [00:11:55] PredictRaw: 0.897783s, 100 calls @ 897783us
#
# [00:11:55] UpdateOneIter: 3.40567s, 100 calls @ 3405673us
#
# [00:11:55] ======== Monitor (0): GBLinear ========
# [00:11:55] DoBoost: 1.90774s, 100 calls @ 1907743us
#
# [00:11:55] PredictBatch: 0.897305s, 100 calls @ 897305us
#
# [00:11:55] PredictBatchInternal: 0.897081s, 100 calls @ 897081us
#
# [00:12:00] ======== Monitor (0): Learner ========
# [00:12:00] Configure: 0.001036s, 1 calls @ 1036us
#
# [00:12:00] EvalOneIter: 0.001925s, 100 calls @ 1925us
#
# [00:12:00] GetGradient: 0.768915s, 100 calls @ 768915us
#
# [00:12:00] PredictRaw: 0.840458s, 100 calls @ 840458us
#
# [00:12:00] UpdateOneIter: 3.89504s, 100 calls @ 3895035us
#
# [00:12:00] ======== Monitor (0): GBLinear ========
# [00:12:00] DoBoost: 2.27224s, 100 calls @ 2272242us
#
# [00:12:00] PredictBatch: 0.840008s, 100 calls @ 840008us
#
# [00:12:00] PredictBatchInternal: 0.839784s, 100 calls @ 839784us
#
# [00:12:03] ======== Monitor (0): Learner ========
# [00:12:03] Configure: 0.000905s, 1 calls @ 905us
#
# [00:12:03] EvalOneIter: 0.012728s, 100 calls @ 12728us
#
# [00:12:03] GetGradient: 0.302351s, 100 calls @ 302351us
#
# [00:12:03] PredictRaw: 0.498458s, 100 calls @ 498458us
#
# [00:12:03] UpdateOneIter: 2.26357s, 100 calls @ 2263570us
#
# [00:12:03] ======== Monitor (0): GBLinear ========
# [00:12:03] DoBoost: 1.46072s, 100 calls @ 1460719us
#
# [00:12:03] PredictBatch: 0.498099s, 100 calls @ 498099us
#
# [00:12:03] PredictBatchInternal: 0.497901s, 100 calls @ 497901us
#
# [00:12:05] ======== Monitor (0): Learner ========
# [00:12:05] Configure: 0.001125s, 1 calls @ 1125us
#
# [00:12:05] EvalOneIter: 0.002157s, 150 calls @ 2157us
#
# [00:12:05] GetGradient: 0.233769s, 150 calls @ 233769us
#
# [00:12:05] PredictRaw: 0.498256s, 150 calls @ 498256us
#
# [00:12:05] UpdateOneIter: 1.53384s, 150 calls @ 1533836us
#
# [00:12:05] ======== Monitor (0): GBLinear ========
# [00:12:05] DoBoost: 0.768207s, 150 calls @ 768207us
#
# [00:12:05] PredictBatch: 0.497882s, 150 calls @ 497882us
#
# [00:12:05] PredictBatchInternal: 0.497659s, 150 calls @ 497659us
#
# [00:12:07] ======== Monitor (0): Learner ========
# [00:12:07] Configure: 0.001029s, 1 calls @ 1029us
#
# [00:12:07] EvalOneIter: 0.001768s, 150 calls @ 1768us
#
# [00:12:07] GetGradient: 0.161132s, 150 calls @ 161132us
#
# [00:12:07] PredictRaw: 0.500762s, 150 calls @ 500762us
#
# [00:12:07] UpdateOneIter: 1.37044s, 150 calls @ 1370439us
#
# [00:12:07] ======== Monitor (0): GBLinear ========
# [00:12:07] DoBoost: 0.706245s, 150 calls @ 706245us
#
# [00:12:07] PredictBatch: 0.500399s, 150 calls @ 500399us
#
# [00:12:07] PredictBatchInternal: 0.500189s, 150 calls @ 500189us
#
# [00:12:08] ======== Monitor (0): Learner ========
# [00:12:08] Configure: 0.000806s, 1 calls @ 806us
#
# [00:12:08] EvalOneIter: 0.001997s, 150 calls @ 1997us
#
# [00:12:08] GetGradient: 0.077929s, 150 calls @ 77929us
#
# [00:12:08] PredictRaw: 0.353873s, 150 calls @ 353873us
#
# [00:12:08] UpdateOneIter: 0.971549s, 150 calls @ 971549us
#
# [00:12:08] ======== Monitor (0): GBLinear ========
# [00:12:08] DoBoost: 0.537788s, 150 calls @ 537788us
#
# [00:12:08] PredictBatch: 0.353559s, 150 calls @ 353559us
#
# [00:12:08] PredictBatchInternal: 0.353375s, 150 calls @ 353375us
#
# [00:12:10] ======== Monitor (0): Learner ========
# [00:12:10] Configure: 0.011226s, 1 calls @ 11226us
#
# [00:12:10] EvalOneIter: 0.002026s, 150 calls @ 2026us
#
# [00:12:10] GetGradient: 0.115631s, 150 calls @ 115631us
#
# [00:12:10] PredictRaw: 0.156432s, 150 calls @ 156432us
#
# [00:12:10] UpdateOneIter: 0.886779s, 150 calls @ 886779us
#
# [00:12:10] ======== Monitor (0): GBLinear ========
# [00:12:10] DoBoost: 0.60248s, 150 calls @ 602480us
#
# [00:12:10] PredictBatch: 0.156184s, 150 calls @ 156184us
#
# [00:12:10] PredictBatchInternal: 0.15601s, 150 calls @ 156010us
#
# [00:12:11] ======== Monitor (0): Learner ========
# [00:12:11] Configure: 0.000783s, 1 calls @ 783us
#
# [00:12:11] EvalOneIter: 0.001915s, 150 calls @ 1915us
#
# [00:12:11] GetGradient: 0.027845s, 150 calls @ 27845us
#
# [00:12:11] PredictRaw: 0.125944s, 150 calls @ 125944us
#
# [00:12:11] UpdateOneIter: 0.649947s, 150 calls @ 649947us
#
# [00:12:11] ======== Monitor (0): GBLinear ========
# [00:12:11] DoBoost: 0.492808s, 150 calls @ 492808us
#
# [00:12:11] PredictBatch: 0.125671s, 150 calls @ 125671us
#
# [00:12:11] PredictBatchInternal: 0.125491s, 150 calls @ 125491us
#
# [00:12:14] ======== Monitor (0): Learner ========
# [00:12:14] Configure: 0.009126s, 1 calls @ 9126us
#
# [00:12:14] EvalOneIter: 0.010383s, 150 calls @ 10383us
#
# [00:12:14] GetGradient: 0.509288s, 150 calls @ 509288us
#
# [00:12:14] PredictRaw: 0.533428s, 150 calls @ 533428us
#
# [00:12:14] UpdateOneIter: 3.05208s, 150 calls @ 3052080us
#
# [00:12:14] ======== Monitor (0): GBLinear ========
# [00:12:14] DoBoost: 1.99845s, 150 calls @ 1998445us
#
# [00:12:14] PredictBatch: 0.532922s, 150 calls @ 532922us
#
# [00:12:14] PredictBatchInternal: 0.532636s, 150 calls @ 532636us
#
# [00:12:15] ======== Monitor (0): Learner ========
# [00:12:15] Configure: 0.001118s, 1 calls @ 1118us
#
# [00:12:15] EvalOneIter: 0.000714s, 50 calls @ 714us
#
# [00:12:15] GetGradient: 0.133713s, 50 calls @ 133713us
#
# [00:12:15] PredictRaw: 0.171708s, 50 calls @ 171708us
#
# [00:12:15] UpdateOneIter: 0.862862s, 50 calls @ 862862us
#
# [00:12:15] ======== Monitor (0): GBLinear ========
# [00:12:15] DoBoost: 0.504886s, 50 calls @ 504886us
#
# [00:12:15] PredictBatch: 0.171534s, 50 calls @ 171534us
#
# [00:12:15] PredictBatchInternal: 0.17143s, 50 calls @ 171430us
#
# [00:12:16] ======== Monitor (0): Learner ========
# [00:12:16] Configure: 0.000856s, 1 calls @ 856us
#
# [00:12:16] EvalOneIter: 0.000656s, 50 calls @ 656us
#
# [00:12:16] GetGradient: 0.010137s, 50 calls @ 10137us
#
# [00:12:16] PredictRaw: 0.069808s, 50 calls @ 69808us
#
# [00:12:16] UpdateOneIter: 0.201514s, 50 calls @ 201514us
#
# [00:12:16] ======== Monitor (0): GBLinear ========
# [00:12:16] DoBoost: 0.120098s, 50 calls @ 120098us
#
# [00:12:16] PredictBatch: 0.069696s, 50 calls @ 69696us
#
# [00:12:16] PredictBatchInternal: 0.069629s, 50 calls @ 69629us
#
# [00:12:16] ======== Monitor (0): Learner ========
# [00:12:16] Configure: 0.000889s, 1 calls @ 889us
#
# [00:12:16] EvalOneIter: 0.000752s, 50 calls @ 752us
#
# [00:12:16] GetGradient: 0.011631s, 50 calls @ 11631us
#
# [00:12:16] PredictRaw: 0.09699s, 50 calls @ 96990us
#
# [00:12:16] UpdateOneIter: 0.201057s, 50 calls @ 201057us
#
# [00:12:16] ======== Monitor (0): GBLinear ========
# [00:12:16] DoBoost: 0.091095s, 50 calls @ 91095us
#
# [00:12:16] PredictBatch: 0.096363s, 50 calls @ 96363us
#
# [00:12:16] PredictBatchInternal: 0.096292s, 50 calls @ 96292us
#
# [00:12:17] ======== Monitor (0): Learner ========
# [00:12:17] Configure: 0.000784s, 1 calls @ 784us
#
# [00:12:17] EvalOneIter: 0.000496s, 50 calls @ 496us
#
# [00:12:17] GetGradient: 0.002618s, 50 calls @ 2618us
#
# [00:12:17] PredictRaw: 0.022724s, 50 calls @ 22724us
#
# [00:12:17] UpdateOneIter: 0.184268s, 50 calls @ 184268us
#
# [00:12:17] ======== Monitor (0): GBLinear ========
# [00:12:17] DoBoost: 0.157873s, 50 calls @ 157873us
#
# [00:12:17] PredictBatch: 0.022654s, 50 calls @ 22654us
#
# [00:12:17] PredictBatchInternal: 0.02259s, 50 calls @ 22590us
#
# [00:12:17] ======== Monitor (0): Learner ========
# [00:12:17] Configure: 0.000774s, 1 calls @ 774us
#
# [00:12:17] EvalOneIter: 0.000549s, 50 calls @ 549us
#
# [00:12:17] GetGradient: 0.002763s, 50 calls @ 2763us
#
# [00:12:17] PredictRaw: 0.017243s, 50 calls @ 17243us
#
# [00:12:17] UpdateOneIter: 0.165462s, 50 calls @ 165462us
#
# [00:12:17] ======== Monitor (0): GBLinear ========
# [00:12:17] DoBoost: 0.144409s, 50 calls @ 144409us
#
# [00:12:17] PredictBatch: 0.017163s, 50 calls @ 17163us
#
# [00:12:17] PredictBatchInternal: 0.01711s, 50 calls @ 17110us
#
# [00:12:17] ======== Monitor (0): Learner ========
# [00:12:17] Configure: 0.00079s, 1 calls @ 790us
#
# [00:12:17] EvalOneIter: 0.000566s, 50 calls @ 566us
#
# [00:12:17] GetGradient: 0.002735s, 50 calls @ 2735us
#
# [00:12:17] PredictRaw: 0.017793s, 50 calls @ 17793us
#
# [00:12:17] UpdateOneIter: 0.163615s, 50 calls @ 163615us
#
# [00:12:17] ======== Monitor (0): GBLinear ========
# [00:12:17] DoBoost: 0.142008s, 50 calls @ 142008us
#
# [00:12:17] PredictBatch: 0.017725s, 50 calls @ 17725us
#
# [00:12:17] PredictBatchInternal: 0.017677s, 50 calls @ 17677us
#
# [00:12:17] ======== Monitor (0): Learner ========
# [00:12:17] Configure: 0.000802s, 1 calls @ 802us
#
# [00:12:17] EvalOneIter: 0.000628s, 100 calls @ 628us
#
# [00:12:17] GetGradient: 0.003323s, 100 calls @ 3323us
#
# [00:12:17] PredictRaw: 0.04135s, 100 calls @ 41350us
#
# [00:12:17] UpdateOneIter: 0.152939s, 100 calls @ 152939us
#
# [00:12:17] ======== Monitor (0): GBLinear ========
# [00:12:17] DoBoost: 0.106956s, 100 calls @ 106956us
#
# [00:12:17] PredictBatch: 0.041231s, 100 calls @ 41231us
#
# [00:12:17] PredictBatchInternal: 0.041144s, 100 calls @ 41144us
#
# [00:12:18] ======== Monitor (0): Learner ========
# [00:12:18] Configure: 0.000815s, 1 calls @ 815us
#
# [00:12:18] EvalOneIter: 0.000573s, 100 calls @ 573us
#
# [00:12:18] GetGradient: 0.003914s, 100 calls @ 3914us
#
# [00:12:18] PredictRaw: 0.033659s, 100 calls @ 33659us
#
# [00:12:18] UpdateOneIter: 0.139881s, 100 calls @ 139881us
#
# [00:12:18] ======== Monitor (0): GBLinear ========
# [00:12:18] DoBoost: 0.101003s, 100 calls @ 101003us
#
# [00:12:18] PredictBatch: 0.033542s, 100 calls @ 33542us
#
# [00:12:18] PredictBatchInternal: 0.033463s, 100 calls @ 33463us
#
# [00:12:18] ======== Monitor (0): Learner ========
# [00:12:18] Configure: 0.00081s, 1 calls @ 810us
#
# [00:12:18] EvalOneIter: 0.000496s, 100 calls @ 496us
#
# [00:12:18] GetGradient: 0.003146s, 100 calls @ 3146us
#
# [00:12:18] PredictRaw: 0.035085s, 100 calls @ 35085us
#
# [00:12:18] UpdateOneIter: 0.141656s, 100 calls @ 141656us
#
# [00:12:18] ======== Monitor (0): GBLinear ========
# [00:12:18] DoBoost: 0.1021s, 100 calls @ 102100us
#
# [00:12:18] PredictBatch: 0.034983s, 100 calls @ 34983us
#
# [00:12:18] PredictBatchInternal: 0.034916s, 100 calls @ 34916us
#
# [00:12:19] ======== Monitor (0): Learner ========
# [00:12:19] Configure: 0.000802s, 1 calls @ 802us
#
# [00:12:19] EvalOneIter: 0.001078s, 100 calls @ 1078us
#
# [00:12:19] GetGradient: 0.00527s, 100 calls @ 5270us
#
# [00:12:19] PredictRaw: 0.031439s, 100 calls @ 31439us
#
# [00:12:19] UpdateOneIter: 0.378787s, 100 calls @ 378787us
#
# [00:12:19] ======== Monitor (0): GBLinear ========
# [00:12:19] DoBoost: 0.340703s, 100 calls @ 340703us
#
# [00:12:19] PredictBatch: 0.031307s, 100 calls @ 31307us
#
# [00:12:19] PredictBatchInternal: 0.031194s, 100 calls @ 31194us
#
# [00:12:19] ======== Monitor (0): Learner ========
# [00:12:19] Configure: 0.000829s, 1 calls @ 829us
#
# [00:12:19] EvalOneIter: 0.001256s, 100 calls @ 1256us
#
# [00:12:19] GetGradient: 0.005371s, 100 calls @ 5371us
#
# [00:12:19] PredictRaw: 0.03039s, 100 calls @ 30390us
#
# [00:12:19] UpdateOneIter: 0.357184s, 100 calls @ 357184us
#
# [00:12:19] ======== Monitor (0): GBLinear ========
# [00:12:19] DoBoost: 0.319985s, 100 calls @ 319985us
#
# [00:12:19] PredictBatch: 0.030227s, 100 calls @ 30227us
#
# [00:12:19] PredictBatchInternal: 0.0301s, 100 calls @ 30100us
#
# [00:12:20] ======== Monitor (0): Learner ========
# [00:12:20] Configure: 0.000827s, 1 calls @ 827us
#
# [00:12:20] EvalOneIter: 0.00125s, 100 calls @ 1250us
#
# [00:12:20] GetGradient: 0.005541s, 100 calls @ 5541us
#
# [00:12:20] PredictRaw: 0.038377s, 100 calls @ 38377us
#
# [00:12:20] UpdateOneIter: 0.393558s, 100 calls @ 393558us
#
# [00:12:20] ======== Monitor (0): GBLinear ========
# [00:12:20] DoBoost: 0.34804s, 100 calls @ 348040us
#
# [00:12:20] PredictBatch: 0.038203s, 100 calls @ 38203us
#
# [00:12:20] PredictBatchInternal: 0.038054s, 100 calls @ 38054us
#
# [00:12:20] ======== Monitor (0): Learner ========
# [00:12:20] Configure: 0.000821s, 1 calls @ 821us
#
# [00:12:20] EvalOneIter: 0.000775s, 150 calls @ 775us
#
# [00:12:20] GetGradient: 0.005586s, 150 calls @ 5586us
#
# [00:12:20] PredictRaw: 0.045824s, 150 calls @ 45824us
#
# [00:12:20] UpdateOneIter: 0.20563s, 150 calls @ 205630us
#
# [00:12:20] ======== Monitor (0): GBLinear ========
# [00:12:20] DoBoost: 0.152627s, 150 calls @ 152627us
#
# [00:12:20] PredictBatch: 0.04563s, 150 calls @ 45630us
#
# [00:12:20] PredictBatchInternal: 0.045509s, 150 calls @ 45509us
#
# [00:12:21] ======== Monitor (0): Learner ========
# [00:12:21] Configure: 0.000813s, 1 calls @ 813us
#
# [00:12:21] EvalOneIter: 0.00093s, 150 calls @ 930us
#
# [00:12:21] GetGradient: 0.00545s, 150 calls @ 5450us
#
# [00:12:21] PredictRaw: 0.047559s, 150 calls @ 47559us
#
# [00:12:21] UpdateOneIter: 0.20995s, 150 calls @ 209950us
#
# [00:12:21] ======== Monitor (0): GBLinear ========
# [00:12:21] DoBoost: 0.155327s, 150 calls @ 155327us
#
# [00:12:21] PredictBatch: 0.047351s, 150 calls @ 47351us
#
# [00:12:21] PredictBatchInternal: 0.04721s, 150 calls @ 47210us
#
# [00:12:21] ======== Monitor (0): Learner ========
# [00:12:21] Configure: 0.000831s, 1 calls @ 831us
#
# [00:12:21] EvalOneIter: 0.000936s, 150 calls @ 936us
#
# [00:12:21] GetGradient: 0.00485s, 150 calls @ 4850us
#
# [00:12:21] PredictRaw: 0.051158s, 150 calls @ 51158us
#
# [00:12:21] UpdateOneIter: 0.207574s, 150 calls @ 207574us
#
# [00:12:21] ======== Monitor (0): GBLinear ========
# [00:12:21] DoBoost: 0.150048s, 150 calls @ 150048us
#
# [00:12:21] PredictBatch: 0.050975s, 150 calls @ 50975us
#
# [00:12:21] PredictBatchInternal: 0.050845s, 150 calls @ 50845us
#
# [00:12:22] ======== Monitor (0): Learner ========
# [00:12:22] Configure: 0.000808s, 1 calls @ 808us
#
# [00:12:22] EvalOneIter: 0.001764s, 150 calls @ 1764us
#
# [00:12:22] GetGradient: 0.008384s, 150 calls @ 8384us
#
# [00:12:22] PredictRaw: 0.065222s, 150 calls @ 65222us
#
# [00:12:22] UpdateOneIter: 0.619973s, 150 calls @ 619973us
#
# [00:12:22] ======== Monitor (0): GBLinear ========
# [00:12:22] DoBoost: 0.543781s, 150 calls @ 543781us
#
# [00:12:22] PredictBatch: 0.064986s, 150 calls @ 64986us
#
# [00:12:22] PredictBatchInternal: 0.064842s, 150 calls @ 64842us
#
# [00:12:23] ======== Monitor (0): Learner ========
# [00:12:23] Configure: 0.00077s, 1 calls @ 770us
#
# [00:12:23] EvalOneIter: 0.00165s, 150 calls @ 1650us
#
# [00:12:23] GetGradient: 0.008002s, 150 calls @ 8002us
#
# [00:12:23] PredictRaw: 0.049596s, 150 calls @ 49596us
#
# [00:12:23] UpdateOneIter: 0.598478s, 150 calls @ 598478us
#
# [00:12:23] ======== Monitor (0): GBLinear ========
# [00:12:23] DoBoost: 0.539139s, 150 calls @ 539139us
#
# [00:12:23] PredictBatch: 0.04935s, 150 calls @ 49350us
#
# [00:12:23] PredictBatchInternal: 0.049136s, 150 calls @ 49136us
#
# [00:12:24] ======== Monitor (0): Learner ========
# [00:12:24] Configure: 0.000807s, 1 calls @ 807us
#
# [00:12:24] EvalOneIter: 0.001419s, 150 calls @ 1419us
#
# [00:12:24] GetGradient: 0.007906s, 150 calls @ 7906us
#
# [00:12:24] PredictRaw: 0.061467s, 150 calls @ 61467us
#
# [00:12:24] UpdateOneIter: 0.619088s, 150 calls @ 619088us
#
# [00:12:24] ======== Monitor (0): GBLinear ========
# [00:12:24] DoBoost: 0.547876s, 150 calls @ 547876us
#
# [00:12:24] PredictBatch: 0.061217s, 150 calls @ 61217us
#
# [00:12:24] PredictBatchInternal: 0.061029s, 150 calls @ 61029us
#
# [00:12:24] ======== Monitor (0): Learner ========
# [00:12:24] Configure: 0.000836s, 1 calls @ 836us
#
# [00:12:24] EvalOneIter: 0.000332s, 50 calls @ 332us
#
# [00:12:24] GetGradient: 0.001596s, 50 calls @ 1596us
#
# [00:12:24] PredictRaw: 0.01616s, 50 calls @ 16160us
#
# [00:12:24] UpdateOneIter: 0.069026s, 50 calls @ 69026us
#
# [00:12:24] ======== Monitor (0): GBLinear ========
# [00:12:24] DoBoost: 0.050131s, 50 calls @ 50131us
#
# [00:12:24] PredictBatch: 0.016101s, 50 calls @ 16101us
#
# [00:12:24] PredictBatchInternal: 0.016065s, 50 calls @ 16065us
#
# [00:12:24] ======== Monitor (0): Learner ========
# [00:12:24] Configure: 0.000828s, 1 calls @ 828us
#
# [00:12:24] EvalOneIter: 0.000335s, 50 calls @ 335us
#
# [00:12:24] GetGradient: 0.001694s, 50 calls @ 1694us
#
# [00:12:24] PredictRaw: 0.015039s, 50 calls @ 15039us
#
# [00:12:24] UpdateOneIter: 0.071471s, 50 calls @ 71471us
#
# [00:12:24] ======== Monitor (0): GBLinear ========
# [00:12:24] DoBoost: 0.053606s, 50 calls @ 53606us
#
# [00:12:24] PredictBatch: 0.01497s, 50 calls @ 14970us
#
# [00:12:24] PredictBatchInternal: 0.014926s, 50 calls @ 14926us
#
# [00:12:24] ======== Monitor (0): Learner ========
# [00:12:24] Configure: 0.000793s, 1 calls @ 793us
#
# [00:12:24] EvalOneIter: 0.000292s, 50 calls @ 292us
#
# [00:12:24] GetGradient: 0.001574s, 50 calls @ 1574us
#
# [00:12:24] PredictRaw: 0.013679s, 50 calls @ 13679us
#
# [00:12:24] UpdateOneIter: 0.06607s, 50 calls @ 66070us
#
# [00:12:24] ======== Monitor (0): GBLinear ========
# [00:12:24] DoBoost: 0.049742s, 50 calls @ 49742us
#
# [00:12:24] PredictBatch: 0.013622s, 50 calls @ 13622us
#
# [00:12:24] PredictBatchInternal: 0.013583s, 50 calls @ 13583us
#
# [00:12:25] ======== Monitor (0): Learner ========
# [00:12:25] Configure: 0.000826s, 1 calls @ 826us
#
# [00:12:25] EvalOneIter: 0.000504s, 50 calls @ 504us
#
# [00:12:25] GetGradient: 0.00289s, 50 calls @ 2890us
#
# [00:12:25] PredictRaw: 0.016042s, 50 calls @ 16042us
#
# [00:12:25] UpdateOneIter: 0.182317s, 50 calls @ 182317us
#
# [00:12:25] ======== Monitor (0): GBLinear ========
# [00:12:25] DoBoost: 0.162289s, 50 calls @ 162289us
#
# [00:12:25] PredictBatch: 0.01597s, 50 calls @ 15970us
#
# [00:12:25] PredictBatchInternal: 0.015913s, 50 calls @ 15913us
#
# [00:12:25] ======== Monitor (0): Learner ========
# [00:12:25] Configure: 0.000793s, 1 calls @ 793us
#
# [00:12:25] EvalOneIter: 0.000436s, 50 calls @ 436us
#
# [00:12:25] GetGradient: 0.003029s, 50 calls @ 3029us
#
# [00:12:25] PredictRaw: 0.015778s, 50 calls @ 15778us
#
# [00:12:25] UpdateOneIter: 0.196284s, 50 calls @ 196284us
#
# [00:12:25] ======== Monitor (0): GBLinear ========
# [00:12:25] DoBoost: 0.176457s, 50 calls @ 176457us
#
# [00:12:25] PredictBatch: 0.015718s, 50 calls @ 15718us
#
# [00:12:25] PredictBatchInternal: 0.015675s, 50 calls @ 15675us
#
# [00:12:25] ======== Monitor (0): Learner ========
# [00:12:25] Configure: 0.000791s, 1 calls @ 791us
#
# [00:12:25] EvalOneIter: 0.000381s, 50 calls @ 381us
#
# [00:12:25] GetGradient: 0.002521s, 50 calls @ 2521us
#
# [00:12:25] PredictRaw: 0.017733s, 50 calls @ 17733us
#
# [00:12:25] UpdateOneIter: 0.183111s, 50 calls @ 183111us
#
# [00:12:25] ======== Monitor (0): GBLinear ========
# [00:12:25] DoBoost: 0.161835s, 50 calls @ 161835us
#
# [00:12:25] PredictBatch: 0.017672s, 50 calls @ 17672us
#
# [00:12:25] PredictBatchInternal: 0.017631s, 50 calls @ 17631us
#
# [00:12:26] ======== Monitor (0): Learner ========
# [00:12:26] Configure: 0.000801s, 1 calls @ 801us
#
# [00:12:26] EvalOneIter: 0.00051s, 100 calls @ 510us
#
# [00:12:26] GetGradient: 0.003124s, 100 calls @ 3124us
#
# [00:12:26] PredictRaw: 0.031976s, 100 calls @ 31976us
#
# [00:12:26] UpdateOneIter: 0.142659s, 100 calls @ 142659us
#
# [00:12:26] ======== Monitor (0): GBLinear ========
# [00:12:26] DoBoost: 0.106302s, 100 calls @ 106302us
#
# [00:12:26] PredictBatch: 0.031867s, 100 calls @ 31867us
#
# [00:12:26] PredictBatchInternal: 0.031791s, 100 calls @ 31791us
#
# [00:12:26] ======== Monitor (0): Learner ========
# [00:12:26] Configure: 0.000792s, 1 calls @ 792us
#
# [00:12:26] EvalOneIter: 0.000552s, 100 calls @ 552us
#
# [00:12:26] GetGradient: 0.004474s, 100 calls @ 4474us
#
# [00:12:26] PredictRaw: 0.045181s, 100 calls @ 45181us
#
# [00:12:26] UpdateOneIter: 0.162165s, 100 calls @ 162165us
#
# [00:12:26] ======== Monitor (0): GBLinear ========
# [00:12:26] DoBoost: 0.111259s, 100 calls @ 111259us
#
# [00:12:26] PredictBatch: 0.045075s, 100 calls @ 45075us
#
# [00:12:26] PredictBatchInternal: 0.044998s, 100 calls @ 44998us
#
# [00:12:26] ======== Monitor (0): Learner ========
# [00:12:26] Configure: 0.000833s, 1 calls @ 833us
#
# [00:12:26] EvalOneIter: 0.000455s, 100 calls @ 455us
#
# [00:12:26] GetGradient: 0.003069s, 100 calls @ 3069us
#
# [00:12:26] PredictRaw: 0.026464s, 100 calls @ 26464us
#
# [00:12:26] UpdateOneIter: 0.128162s, 100 calls @ 128162us
#
# [00:12:26] ======== Monitor (0): GBLinear ========
# [00:12:26] DoBoost: 0.097385s, 100 calls @ 97385us
#
# [00:12:26] PredictBatch: 0.02636s, 100 calls @ 26360us
#
# [00:12:26] PredictBatchInternal: 0.026288s, 100 calls @ 26288us
#
# [00:12:28] ======== Monitor (0): Learner ========
# [00:12:28] Configure: 0.000786s, 1 calls @ 786us
#
# [00:12:28] EvalOneIter: 0.001535s, 100 calls @ 1535us
#
# [00:12:28] GetGradient: 0.19645s, 100 calls @ 196450us
#
# [00:12:28] PredictRaw: 0.262241s, 100 calls @ 262241us
#
# [00:12:28] UpdateOneIter: 1.53656s, 100 calls @ 1536564us
#
# [00:12:28] ======== Monitor (0): GBLinear ========
# [00:12:28] DoBoost: 1.07617s, 100 calls @ 1076171us
#
# [00:12:28] PredictBatch: 0.261966s, 100 calls @ 261966us
#
# [00:12:28] PredictBatchInternal: 0.261789s, 100 calls @ 261789us
#
# [00:12:30] ======== Monitor (0): Learner ========
# [00:12:30] Configure: 0.000807s, 1 calls @ 807us
#
# [00:12:30] EvalOneIter: 0.001653s, 100 calls @ 1653us
#
# [00:12:30] GetGradient: 0.287198s, 100 calls @ 287198us
#
# [00:12:30] PredictRaw: 0.427121s, 100 calls @ 427121us
#
# [00:12:30] UpdateOneIter: 2.04034s, 100 calls @ 2040338us
#
# [00:12:30] ======== Monitor (0): GBLinear ========
# [00:12:30] DoBoost: 1.32414s, 100 calls @ 1324143us
#
# [00:12:30] PredictBatch: 0.426802s, 100 calls @ 426802us
#
# [00:12:30] PredictBatchInternal: 0.426593s, 100 calls @ 426593us
#
# [00:12:32] ======== Monitor (0): Learner ========
# [00:12:32] Configure: 0.001075s, 1 calls @ 1075us
#
# [00:12:32] EvalOneIter: 0.004302s, 100 calls @ 4302us
#
# [00:12:32] GetGradient: 0.116212s, 100 calls @ 116212us
#
# [00:12:32] PredictRaw: 0.270981s, 100 calls @ 270981us
#
# [00:12:32] UpdateOneIter: 1.27073s, 100 calls @ 1270730us
#
# [00:12:32] ======== Monitor (0): GBLinear ========
# [00:12:32] DoBoost: 0.881454s, 100 calls @ 881454us
#
# [00:12:32] PredictBatch: 0.27071s, 100 calls @ 270710us
#
# [00:12:32] PredictBatchInternal: 0.270513s, 100 calls @ 270513us
#
# [00:12:33] ======== Monitor (0): Learner ========
# [00:12:33] Configure: 0.001007s, 1 calls @ 1007us
#
# [00:12:33] EvalOneIter: 0.001121s, 150 calls @ 1121us
#
# [00:12:33] GetGradient: 0.023908s, 150 calls @ 23908us
#
# [00:12:33] PredictRaw: 0.14028s, 150 calls @ 140280us
#
# [00:12:33] UpdateOneIter: 0.338874s, 150 calls @ 338874us
#
# [00:12:33] ======== Monitor (0): GBLinear ========
# [00:12:33] DoBoost: 0.172962s, 150 calls @ 172962us
#
# [00:12:33] PredictBatch: 0.140066s, 150 calls @ 140066us
#
# [00:12:33] PredictBatchInternal: 0.139945s, 150 calls @ 139945us
#
# [00:12:33] ======== Monitor (0): Learner ========
# [00:12:33] Configure: 0.000831s, 1 calls @ 831us
#
# [00:12:33] EvalOneIter: 0.000856s, 150 calls @ 856us
#
# [00:12:33] GetGradient: 0.004931s, 150 calls @ 4931us
#
# [00:12:33] PredictRaw: 0.052461s, 150 calls @ 52461us
#
# [00:12:33] UpdateOneIter: 0.214584s, 150 calls @ 214584us
#
# [00:12:33] ======== Monitor (0): GBLinear ========
# [00:12:33] DoBoost: 0.15569s, 150 calls @ 155690us
#
# [00:12:33] PredictBatch: 0.052285s, 150 calls @ 52285us
#
# [00:12:33] PredictBatchInternal: 0.052172s, 150 calls @ 52172us
#
# [00:12:34] ======== Monitor (0): Learner ========
# [00:12:34] Configure: 0.000802s, 1 calls @ 802us
#
# [00:12:34] EvalOneIter: 0.001182s, 150 calls @ 1182us
#
# [00:12:34] GetGradient: 0.005201s, 150 calls @ 5201us
#
# [00:12:34] PredictRaw: 0.050574s, 150 calls @ 50574us
#
# [00:12:34] UpdateOneIter: 0.215685s, 150 calls @ 215685us
#
# [00:12:34] ======== Monitor (0): GBLinear ========
# [00:12:34] DoBoost: 0.158412s, 150 calls @ 158412us
#
# [00:12:34] PredictBatch: 0.050388s, 150 calls @ 50388us
#
# [00:12:34] PredictBatchInternal: 0.050247s, 150 calls @ 50247us
#
# [00:12:35] ======== Monitor (0): Learner ========
# [00:12:35] Configure: 0.000798s, 1 calls @ 798us
#
# [00:12:35] EvalOneIter: 0.001887s, 150 calls @ 1887us
#
# [00:12:35] GetGradient: 0.00997s, 150 calls @ 9970us
#
# [00:12:35] PredictRaw: 0.047834s, 150 calls @ 47834us
#
# [00:12:35] UpdateOneIter: 0.624884s, 150 calls @ 624884us
#
# [00:12:35] ======== Monitor (0): GBLinear ========
# [00:12:35] DoBoost: 0.565307s, 150 calls @ 565307us
#
# [00:12:35] PredictBatch: 0.047592s, 150 calls @ 47592us
#
# [00:12:35] PredictBatchInternal: 0.047418s, 150 calls @ 47418us
#
# [00:12:36] ======== Monitor (0): Learner ========
# [00:12:36] Configure: 0.000786s, 1 calls @ 786us
#
# [00:12:36] EvalOneIter: 0.001615s, 150 calls @ 1615us
#
# [00:12:36] GetGradient: 0.00773s, 150 calls @ 7730us
#
# [00:12:36] PredictRaw: 0.053908s, 150 calls @ 53908us
#
# [00:12:36] UpdateOneIter: 0.616847s, 150 calls @ 616847us
#
# [00:12:36] ======== Monitor (0): GBLinear ========
# [00:12:36] DoBoost: 0.553585s, 150 calls @ 553585us
#
# [00:12:36] PredictBatch: 0.053688s, 150 calls @ 53688us
#
# [00:12:36] PredictBatchInternal: 0.053513s, 150 calls @ 53513us
#
# [00:12:36] ======== Monitor (0): Learner ========
# [00:12:36] Configure: 0.000775s, 1 calls @ 775us
#
# [00:12:36] EvalOneIter: 0.001464s, 150 calls @ 1464us
#
# [00:12:36] GetGradient: 0.008857s, 150 calls @ 8857us
#
# [00:12:36] PredictRaw: 0.049594s, 150 calls @ 49594us
#
# [00:12:36] UpdateOneIter: 0.644655s, 150 calls @ 644655us
#
# [00:12:36] ======== Monitor (0): GBLinear ========
# [00:12:36] DoBoost: 0.584424s, 150 calls @ 584424us
#
# [00:12:36] PredictBatch: 0.049357s, 150 calls @ 49357us
#
# [00:12:36] PredictBatchInternal: 0.049186s, 150 calls @ 49186us
#
# [00:12:38] ======== Monitor (0): Learner ========
# [00:12:38] Configure: 0.00078s, 1 calls @ 780us
#
# [00:12:38] EvalOneIter: 0.002187s, 150 calls @ 2187us
#
# [00:12:38] GetGradient: 0.011297s, 150 calls @ 11297us
#
# [00:12:38] PredictRaw: 0.078969s, 150 calls @ 78969us
#
# [00:12:38] UpdateOneIter: 0.923579s, 150 calls @ 923579us
#
# [00:12:38] ======== Monitor (0): GBLinear ========
# [00:12:38] DoBoost: 0.831344s, 150 calls @ 831344us
#
# [00:12:38] PredictBatch: 0.078566s, 150 calls @ 78566us
#
# [00:12:38] PredictBatchInternal: 0.078334s, 150 calls @ 78334us
#
# Meilleurs hyperparamèetres:
#     booster  enable_categorical  learning_rate  n_estimators     objective
# 0  gblinear                True            0.1           150  binary:hinge
#
# Meilleur score: 0.918589346310498

# %%
xgb_acc = {}
xgb_f1 = {}

# %% [markdown]
# Meilleur modèle XGBoost:

# %%
xgbClassifier_optimized = xgb.XGBClassifier(**best_parameters, random_state=42)

# %% [markdown]
# ## Simplified + One hot

# %%
xgbClassifier_optimized.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_simplified_oneHot, y_test_simplified_oneHot)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_simplified_oneHot)
xgbClassifier_optimized_f1 = f1_score(y_test_simplified_oneHot, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Simplified + OneHot"] = xgbClassifier_optimized_acc
xgb_f1["Simplified + OneHot"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Original + One hot

# %%
xgbClassifier_optimized.fit(X_train_original_oneHot, y_train_original_oneHot)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_original_oneHot, y_test_original_oneHot)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_original_oneHot)
xgbClassifier_optimized_f1 = f1_score(y_test_original_oneHot, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Original + OneHot"] = xgbClassifier_optimized_acc
xgb_f1["Original + OneHot"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Simplified

# %%
xgbClassifier_optimized.fit(X_train_simplified, y_train_simplified)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_simplified, y_test_simplified)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_simplified)
xgbClassifier_optimized_f1 = f1_score(y_test_simplified, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Simplified"] = xgbClassifier_optimized_acc
xgb_f1["Simplified"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
xgbClassifier_optimized.fit(X_train_original, y_train_original)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_original, y_test_original)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_original)
xgbClassifier_optimized_f1 = f1_score(y_test_original, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Original"] = xgbClassifier_optimized_acc
xgb_f1["Original"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["XGboost"] = xgb_acc
dict_f1["XGboost"] = xgb_f1

# %% [markdown]
# # SVC

# %% [markdown]
# ## Recherche en grille

# %% [markdown]
# Pour le SVC, le choix du kernel doit obligatoirement être linéaire, puisque cela empêche au modèle d'augmenter la dimensionnalité des données, ce qui nous empêcherait plus tard de faire une analyse claire des features les plus prenants pour la classification.
#
# L'utilisation d'un noyeau linéaire permet au SVM de rester dans l'espace dimensionnel de base et ne projète pas les features dans un espace à plus haute dimensionnalité, comme le ferait un noyeau Gaussien ou RBF, par exemple. C'est pourquoi nous pourrons directement récupérer l'importance des features plus tard dans l'analyse.

# %%
# by default SVC
svcClassifier = SVC(kernel="rbf", C=1.0, degree=3, gamma='scale', random_state=42)

param_grid = {
    'kernel': ['linear'],
    'C': [0.1, 1, 10, 50],
    'gamma': ['scale', 0.001, 0.1, 1],
    'class_weight': [None, 'balanced']
}

# init grid search
grid_search = GridSearchCV(estimator=svcClassifier, param_grid=param_grid, cv=3, scoring='f1', verbose=3)

grid_search.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV 1/3] END C=0.1, class_weight=None, gamma=scale, kernel=linear;, score=0.929 total time=   0.1s
# [CV 2/3] END C=0.1, class_weight=None, gamma=scale, kernel=linear;, score=0.932 total time=   0.2s
# [CV 3/3] END C=0.1, class_weight=None, gamma=scale, kernel=linear;, score=0.923 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=None, gamma=0.001, kernel=linear;, score=0.929 total time=   0.1s
# [CV 2/3] END C=0.1, class_weight=None, gamma=0.001, kernel=linear;, score=0.932 total time=   0.2s
# [CV 3/3] END C=0.1, class_weight=None, gamma=0.001, kernel=linear;, score=0.923 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=None, gamma=0.1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 2/3] END C=0.1, class_weight=None, gamma=0.1, kernel=linear;, score=0.932 total time=   0.2s
# [CV 3/3] END C=0.1, class_weight=None, gamma=0.1, kernel=linear;, score=0.923 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=None, gamma=1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 2/3] END C=0.1, class_weight=None, gamma=1, kernel=linear;, score=0.932 total time=   0.2s
# [CV 3/3] END C=0.1, class_weight=None, gamma=1, kernel=linear;, score=0.923 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.925 total time=   0.2s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.923 total time=   0.3s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.912 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.925 total time=   0.2s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.923 total time=   0.3s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.912 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.925 total time=   0.2s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.923 total time=   0.3s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.912 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=1, kernel=linear;, score=0.925 total time=   0.2s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=1, kernel=linear;, score=0.923 total time=   0.3s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=1, kernel=linear;, score=0.912 total time=   0.2s
# [CV 1/3] END C=1, class_weight=None, gamma=scale, kernel=linear;, score=0.923 total time=   0.6s
# [CV 2/3] END C=1, class_weight=None, gamma=scale, kernel=linear;, score=0.925 total time=   1.0s
# [CV 3/3] END C=1, class_weight=None, gamma=scale, kernel=linear;, score=0.921 total time=   0.6s
# [CV 1/3] END C=1, class_weight=None, gamma=0.001, kernel=linear;, score=0.923 total time=   0.6s
# [CV 2/3] END C=1, class_weight=None, gamma=0.001, kernel=linear;, score=0.925 total time=   0.8s
# [CV 3/3] END C=1, class_weight=None, gamma=0.001, kernel=linear;, score=0.921 total time=   0.4s
# [CV 1/3] END C=1, class_weight=None, gamma=0.1, kernel=linear;, score=0.923 total time=   0.4s
# [CV 2/3] END C=1, class_weight=None, gamma=0.1, kernel=linear;, score=0.925 total time=   0.6s
# [CV 3/3] END C=1, class_weight=None, gamma=0.1, kernel=linear;, score=0.921 total time=   0.4s
# [CV 1/3] END C=1, class_weight=None, gamma=1, kernel=linear;, score=0.923 total time=   0.4s
# [CV 2/3] END C=1, class_weight=None, gamma=1, kernel=linear;, score=0.925 total time=   0.6s
# [CV 3/3] END C=1, class_weight=None, gamma=1, kernel=linear;, score=0.921 total time=   0.4s
# [CV 1/3] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.922 total time=   0.5s
# [CV 2/3] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.917 total time=   0.8s
# [CV 3/3] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.916 total time=   0.4s
# [CV 1/3] END C=1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.922 total time=   0.5s
# [CV 2/3] END C=1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.917 total time=   0.8s
# [CV 3/3] END C=1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.916 total time=   0.4s
# [CV 1/3] END C=1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.922 total time=   0.5s
# [CV 2/3] END C=1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.917 total time=   0.8s
# [CV 3/3] END C=1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.916 total time=   0.4s
# [CV 1/3] END C=1, class_weight=balanced, gamma=1, kernel=linear;, score=0.922 total time=   0.5s
# [CV 2/3] END C=1, class_weight=balanced, gamma=1, kernel=linear;, score=0.917 total time=   0.8s
# [CV 3/3] END C=1, class_weight=balanced, gamma=1, kernel=linear;, score=0.916 total time=   0.5s
# [CV 1/3] END C=10, class_weight=None, gamma=scale, kernel=linear;, score=0.918 total time=   6.3s
# [CV 2/3] END C=10, class_weight=None, gamma=scale, kernel=linear;, score=0.923 total time=   8.5s
# [CV 3/3] END C=10, class_weight=None, gamma=scale, kernel=linear;, score=0.926 total time=   9.3s
# [CV 1/3] END C=10, class_weight=None, gamma=0.001, kernel=linear;, score=0.918 total time=   4.2s
# [CV 2/3] END C=10, class_weight=None, gamma=0.001, kernel=linear;, score=0.923 total time=   8.3s
# [CV 3/3] END C=10, class_weight=None, gamma=0.001, kernel=linear;, score=0.926 total time=   9.9s
# [CV 1/3] END C=10, class_weight=None, gamma=0.1, kernel=linear;, score=0.918 total time=   3.5s
# [CV 2/3] END C=10, class_weight=None, gamma=0.1, kernel=linear;, score=0.923 total time=  11.7s
# [CV 3/3] END C=10, class_weight=None, gamma=0.1, kernel=linear;, score=0.926 total time=   6.4s
# [CV 1/3] END C=10, class_weight=None, gamma=1, kernel=linear;, score=0.918 total time=   3.5s
# [CV 2/3] END C=10, class_weight=None, gamma=1, kernel=linear;, score=0.923 total time=  11.6s
# [CV 3/3] END C=10, class_weight=None, gamma=1, kernel=linear;, score=0.926 total time=   6.3s
# [CV 1/3] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=0.919 total time=   6.9s
# [CV 2/3] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=0.914 total time=   4.3s
# [CV 3/3] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=0.911 total time=   5.4s
# [CV 1/3] END C=10, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.919 total time=   5.8s
# [CV 2/3] END C=10, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.914 total time=   5.5s
# [CV 3/3] END C=10, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.911 total time=   5.4s
# [CV 1/3] END C=10, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.919 total time=   4.6s
# [CV 2/3] END C=10, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.914 total time=   6.6s
# [CV 3/3] END C=10, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.911 total time=   5.4s
# [CV 1/3] END C=10, class_weight=balanced, gamma=1, kernel=linear;, score=0.919 total time=   4.0s
# [CV 2/3] END C=10, class_weight=balanced, gamma=1, kernel=linear;, score=0.914 total time=   7.1s
# [CV 3/3] END C=10, class_weight=balanced, gamma=1, kernel=linear;, score=0.911 total time=   6.0s
# [CV 1/3] END C=50, class_weight=None, gamma=scale, kernel=linear;, score=0.919 total time=  24.2s
# [CV 2/3] END C=50, class_weight=None, gamma=scale, kernel=linear;, score=0.921 total time=  30.1s
# [CV 3/3] END C=50, class_weight=None, gamma=scale, kernel=linear;, score=0.921 total time=  47.7s
# [CV 1/3] END C=50, class_weight=None, gamma=0.001, kernel=linear;, score=0.919 total time=  24.5s
# [CV 2/3] END C=50, class_weight=None, gamma=0.001, kernel=linear;, score=0.921 total time=  29.0s
# [CV 3/3] END C=50, class_weight=None, gamma=0.001, kernel=linear;, score=0.921 total time=  45.7s
# [CV 1/3] END C=50, class_weight=None, gamma=0.1, kernel=linear;, score=0.919 total time=  26.4s
# [CV 2/3] END C=50, class_weight=None, gamma=0.1, kernel=linear;, score=0.921 total time=  27.8s
# [CV 3/3] END C=50, class_weight=None, gamma=0.1, kernel=linear;, score=0.921 total time=  55.4s
# [CV 1/3] END C=50, class_weight=None, gamma=1, kernel=linear;, score=0.919 total time=  26.6s
# [CV 2/3] END C=50, class_weight=None, gamma=1, kernel=linear;, score=0.921 total time=  27.3s
# [CV 3/3] END C=50, class_weight=None, gamma=1, kernel=linear;, score=0.921 total time=  48.5s
# [CV 1/3] END C=50, class_weight=balanced, gamma=scale, kernel=linear;, score=0.917 total time=  18.5s
# [CV 2/3] END C=50, class_weight=balanced, gamma=scale, kernel=linear;, score=0.911 total time=  34.6s
# [CV 3/3] END C=50, class_weight=balanced, gamma=scale, kernel=linear;, score=0.912 total time=  26.5s
# [CV 1/3] END C=50, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.917 total time=  18.5s
# [CV 2/3] END C=50, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.911 total time=  34.4s
# [CV 3/3] END C=50, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.912 total time=  30.2s
# [CV 1/3] END C=50, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.917 total time=  18.6s
# [CV 2/3] END C=50, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.911 total time=  34.6s
# [CV 3/3] END C=50, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.912 total time=  26.6s
# [CV 1/3] END C=50, class_weight=balanced, gamma=1, kernel=linear;, score=0.917 total time=  18.5s
# [CV 2/3] END C=50, class_weight=balanced, gamma=1, kernel=linear;, score=0.911 total time=  34.3s
# [CV 3/3] END C=50, class_weight=balanced, gamma=1, kernel=linear;, score=0.912 total time=  30.2s
# Meilleurs hyperparamèetres:
#      C class_weight  gamma  kernel
# 0  0.1         None  scale  linear
#
# Meilleur score: 0.9282236041300876

# %%
svc_acc = {}
svc_f1 = {}

# %% [markdown]
# Meilleur modèle SVC:

# %%
svcClassifier_optimized = SVC(**best_parameters, random_state=42)

# %% [markdown]
# ## Simplified + One hot

# %%
svcClassifier_optimized.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_simplified_oneHot, y_test_simplified_oneHot)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_simplified_oneHot)
svcClassifier_optimized_f1 = f1_score(y_test_simplified_oneHot, svcClassifier_optimized_predz, average='binary')

svc_acc["Simplified + OneHot"] = svcClassifier_optimized_acc
svc_f1["Simplified + OneHot"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Original + One hot

# %%
svcClassifier_optimized.fit(X_train_original_oneHot, y_train_original_oneHot)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_original_oneHot, y_test_original_oneHot)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_original_oneHot)
svcClassifier_optimized_f1 = f1_score(y_test_original_oneHot, svcClassifier_optimized_predz, average='binary')

svc_acc["Original + OneHot"] = svcClassifier_optimized_acc
svc_f1["Original + OneHot"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Simplified

# %%
svcClassifier_optimized.fit(X_train_simplified, y_train_simplified)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_simplified, y_test_simplified)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_simplified)
svcClassifier_optimized_f1 = f1_score(y_test_simplified, svcClassifier_optimized_predz, average='binary')

svc_acc["Simplified"] = svcClassifier_optimized_acc
svc_f1["Simplified"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
svcClassifier_optimized.fit(X_train_original, y_train_original)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_original, y_test_original)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_original)
svcClassifier_optimized_f1 = f1_score(y_test_original, svcClassifier_optimized_predz, average='binary')

svc_acc["Original"] = svcClassifier_optimized_acc
svc_f1["Original"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["SVC"] = svc_acc
dict_f1["SVC"] = svc_f1

# %% [markdown]
# # KNN

# %% [markdown]
# ## Recherche en grille

# %%
n_range = 30
mean_acc = np.zeros(n_range)
for i in range(1,n_range + 1):
    #Train Model and Predict
    knn = KNeighborsClassifier(n_neighbors = i).fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
    yhat= knn.predict(X_test_simplified_oneHot)
    mean_acc[i-1] = metrics.accuracy_score(y_test_simplified_oneHot, yhat)
k_range_cnt = 10
k_range = np.argpartition(mean_acc, -k_range_cnt)[-k_range_cnt:]

# by default knn
knnClassifier = KNeighborsClassifier()

param_grid = {
               'n_neighbors' : k_range,
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan'],
               'algorithm' : ['ball_tree', 'kd_tree', 'brute'],
               'p' : [1,2],
}

# init grid search
grid_search = GridSearchCV(estimator=knnClassifier, param_grid=param_grid, cv=3, scoring='f1', verbose=3)

grid_search.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.885 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.888 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.900 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.896 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.880 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.885 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.895 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.881 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=distance;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=distance;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=distance;, score=0.882 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=uniform;, score=0.891 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=uniform;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=distance;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=0.903 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=uniform;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=uniform;, score=0.887 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=distance;, score=0.887 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=uniform;, score=0.906 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=uniform;, score=0.898 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=uniform;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=uniform;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=distance;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=uniform;, score=0.906 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=uniform;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=distance;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=uniform;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=uniform;, score=0.893 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=distance;, score=0.896 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=distance;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=uniform;, score=0.896 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=uniform;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=uniform;, score=0.894 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=distance;, score=0.898 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=uniform;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=uniform;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=uniform;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=distance;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=distance;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=uniform;, score=0.890 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=distance;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=distance;, score=0.894 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=uniform;, score=0.900 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=distance;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=distance;, score=0.885 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=uniform;, score=0.900 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=distance;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=distance;, score=0.885 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=uniform;, score=0.896 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=uniform;, score=0.899 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=uniform;, score=0.880 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=uniform;, score=0.896 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=uniform;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=uniform;, score=0.880 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=uniform;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=uniform;, score=0.881 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=distance;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=distance;, score=0.882 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=uniform;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=uniform;, score=0.881 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=distance;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=distance;, score=0.882 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=uniform;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=distance;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=uniform;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=distance;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=distance;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=distance;, score=0.883 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=distance;, score=0.896 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=uniform;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=distance;, score=0.896 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=uniform;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=uniform;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=distance;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=uniform;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=uniform;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=distance;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=uniform;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=distance;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=uniform;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=distance;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=uniform;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=uniform;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=distance;, score=0.883 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=uniform;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=uniform;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=distance;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=distance;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=uniform;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=uniform;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.894 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.887 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.885 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.888 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.885 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.888 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.897 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.895 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.895 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.891 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.903 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.903 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.898 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.898 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.894 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.906 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.897 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.892 total time=   0.6s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.906 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.892 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.906 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.890 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.896 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.894 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.898 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.896 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.894 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.898 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.890 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.890 total time=   0.6s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.885 total time=   0.6s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.7s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.6s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.888 total time=   0.6s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.6s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.5s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.893 total time=   0.5s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.900 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.896 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.880 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.890 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.891 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.899 total time=   0.3s
# ...
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.886 total time=   0.0s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.1s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.891 total time=   0.1s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.1s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.892 total time=   0.0s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.894 total time=   0.0s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.887 total time=   0.0s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.1s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.891 total time=   0.1s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.1s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.892 total time=   0.0s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.894 total time=   0.0s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.887 total time=   0.0s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.886 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.886 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.905 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.895 total time=   0.5s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.891 total time=   0.7s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.894 total time=   0.7s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.892 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.7s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.894 total time=   0.8s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.890 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.897 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.888 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.888 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.904 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.904 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.905 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.899 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.898 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.899 total time=   0.6s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.894 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.906 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.898 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.905 total time=   0.7s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.890 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.907 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.891 total time=   0.6s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.892 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.905 total time=   0.5s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.890 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.894 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.894 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.897 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.890 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.889 total time=   0.5s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.7s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.893 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.890 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.890 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.897 total time=   0.7s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.889 total time=   0.7s
# Meilleurs hyperparamèetres:
#   algorithm     metric  n_neighbors  p   weights
# 0     brute  minkowski            9  1  distance
#
# Meilleur score: 0.9001954018453863

# %%
knn_acc = {}
knn_f1 = {}

# %% [markdown]
# Meilleur modèle KNN:

# %%
knnClassifier_optimized = KNeighborsClassifier(**best_parameters)

# %% [markdown]
# ## Simplified + One hot

# %%
knnClassifier_optimized.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_simplified_oneHot, y_test_simplified_oneHot)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_simplified_oneHot)
knnClassifier_optimized_f1 = f1_score(y_test_simplified_oneHot, knnClassifier_optimized_predz, average='binary')

knn_acc["Simplified + OneHot"] = knnClassifier_optimized_acc
knn_f1["Simplified + OneHot"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Original + One hot

# %%
knnClassifier_optimized.fit(X_train_original_oneHot, y_train_original_oneHot)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_original_oneHot, y_test_original_oneHot)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_original_oneHot)
knnClassifier_optimized_f1 = f1_score(y_test_original_oneHot, knnClassifier_optimized_predz, average='binary')

knn_acc["Original + OneHot"] = knnClassifier_optimized_acc
knn_f1["Original + OneHot"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Simplified

# %%
knnClassifier_optimized.fit(X_train_simplified, y_train_simplified)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_simplified, y_test_simplified)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_simplified)
knnClassifier_optimized_f1 = f1_score(y_test_simplified, knnClassifier_optimized_predz, average='binary')

knn_acc["Simplified"] = knnClassifier_optimized_acc
knn_f1["Simplified"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
knnClassifier_optimized.fit(X_train_original, y_train_original)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_original, y_test_original)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_original)
knnClassifier_optimized_f1 = f1_score(y_test_original, knnClassifier_optimized_predz, average='binary')

knn_acc["Original"] = knnClassifier_optimized_acc
knn_f1["Original"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["KNN"] = knn_acc
dict_f1["KNN"] = knn_f1

# %% [markdown]
# # CatBoost

# %% [markdown]
# ## Recherche en grille

# %%
# Create a CatBoostClassifier
catboost_model = CatBoostClassifier(cat_features=cat_features_catb, verbose=0, random_state=42)

# Define the parameter grid to search
param_grid = {
    'iterations': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3, 5],
}

# init grid search
grid_search = GridSearchCV(estimator=catboost_model, param_grid=param_grid, scoring='f1', cv=3, verbose=3)

grid_search.fit(X_train_simplified, y_train_simplified)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.919 total time=   0.9s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.917 total time=   0.7s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.897 total time=   0.7s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.924 total time=   0.8s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.930 total time=   0.8s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.914 total time=   0.8s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.928 total time=   0.8s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.927 total time=   0.6s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.922 total time=   0.4s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.919 total time=   0.4s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.917 total time=   0.4s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.894 total time=   0.4s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.930 total time=   0.4s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.927 total time=   0.4s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.916 total time=   0.4s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.928 total time=   0.4s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.932 total time=   0.4s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.921 total time=   0.4s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.918 total time=   0.4s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.917 total time=   0.4s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.894 total time=   0.4s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.927 total time=   0.4s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.926 total time=   0.4s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.918 total time=   0.4s
# [CV 1/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.920 total time=   0.4s
# [CV 2/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.935 total time=   0.4s
# [CV 3/3] END depth=4, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.923 total time=   0.4s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.920 total time=   1.1s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.918 total time=   1.2s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.900 total time=   2.2s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.926 total time=   2.0s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.936 total time=   2.1s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.911 total time=   1.4s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.925 total time=   1.1s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.932 total time=   1.1s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.919 total time=   1.1s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.919 total time=   1.1s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.922 total time=   1.1s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.900 total time=   1.1s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.924 total time=   1.1s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.933 total time=   1.1s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.914 total time=   1.7s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.926 total time=   2.0s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.933 total time=   2.2s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.921 total time=   2.0s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.921 total time=   1.1s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.921 total time=   1.1s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.899 total time=   1.1s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.928 total time=   1.1s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.928 total time=   1.1s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.921 total time=   1.1s
# [CV 1/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.920 total time=   1.1s
# [CV 2/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.933 total time=   1.1s
# [CV 3/3] END depth=4, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.915 total time=   1.2s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.921 total time=   3.0s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.926 total time=   3.1s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.909 total time=   2.0s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.924 total time=   1.6s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.934 total time=   1.6s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.917 total time=   1.6s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.923 total time=   1.6s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.936 total time=   1.6s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.916 total time=   2.7s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.920 total time=   3.2s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.925 total time=   2.4s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.909 total time=   1.6s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.924 total time=   1.6s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.934 total time=   1.6s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.916 total time=   1.6s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.927 total time=   1.6s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.935 total time=   1.8s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.921 total time=   3.1s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.921 total time=   4.0s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.925 total time=   2.0s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.906 total time=   2.0s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.924 total time=   1.7s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.929 total time=   1.6s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.923 total time=   1.6s
# [CV 1/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.921 total time=   2.7s
# [CV 2/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.934 total time=   3.2s
# [CV 3/3] END depth=4, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.916 total time=   2.4s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.914 total time=   0.6s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.919 total time=   0.6s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.898 total time=   0.6s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.929 total time=   0.6s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.929 total time=   0.6s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.916 total time=   0.6s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.926 total time=   0.6s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.932 total time=   0.5s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.916 total time=   0.6s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.917 total time=   0.6s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.918 total time=   0.6s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.897 total time=   0.6s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.925 total time=   0.6s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.926 total time=   0.6s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.921 total time=   0.6s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.926 total time=   0.6s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.937 total time=   0.9s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.922 total time=   1.1s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.915 total time=   1.2s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.919 total time=   1.1s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.897 total time=   1.2s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.925 total time=   1.0s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.933 total time=   0.8s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.918 total time=   0.6s
# [CV 1/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.925 total time=   0.6s
# [CV 2/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.935 total time=   0.6s
# [CV 3/3] END depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.919 total time=   0.6s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.922 total time=   1.8s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.924 total time=   1.8s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.905 total time=   1.7s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.927 total time=   1.8s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.936 total time=   3.0s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.918 total time=   3.5s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.920 total time=   2.3s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.928 total time=   1.8s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.915 total time=   1.8s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.921 total time=   1.8s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.924 total time=   1.7s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.900 total time=   1.9s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.924 total time=   3.4s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.937 total time=   3.4s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.919 total time=   1.8s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.924 total time=   1.8s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.937 total time=   1.8s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.921 total time=   1.9s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.919 total time=   1.7s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.924 total time=   2.4s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.903 total time=   3.2s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.927 total time=   2.8s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.939 total time=   1.8s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.918 total time=   1.8s
# [CV 1/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.925 total time=   1.8s
# [CV 2/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.934 total time=   1.8s
# [CV 3/3] END depth=6, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.912 total time=   1.8s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.923 total time=   4.5s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.930 total time=   4.2s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.912 total time=   2.5s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.926 total time=   2.7s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.934 total time=   2.7s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.923 total time=   4.2s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.916 total time=   4.7s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.933 total time=   2.7s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.914 total time=   2.8s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.922 total time=   2.6s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.925 total time=   4.0s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.912 total time=   4.6s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.922 total time=   2.6s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.938 total time=   2.7s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.914 total time=   2.7s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.924 total time=   3.7s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.934 total time=   5.1s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.918 total time=   2.8s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.923 total time=   2.6s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.927 total time=   2.6s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.911 total time=   3.3s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.923 total time=   4.8s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.942 total time=   3.1s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.920 total time=   2.7s
# [CV 1/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.923 total time=   2.7s
# [CV 2/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.933 total time=   2.9s
# [CV 3/3] END depth=6, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.912 total time=   5.3s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.917 total time=   1.5s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.921 total time=   0.9s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.01;, score=0.898 total time=   0.9s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.929 total time=   1.0s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.933 total time=   1.0s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.05;, score=0.909 total time=   1.0s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.924 total time=   1.0s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.934 total time=   1.0s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=1, learning_rate=0.1;, score=0.912 total time=   1.0s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.916 total time=   1.0s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.922 total time=   0.9s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.01;, score=0.901 total time=   1.7s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.927 total time=   1.8s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.933 total time=   1.8s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.05;, score=0.915 total time=   1.9s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.921 total time=   1.0s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.930 total time=   1.0s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=3, learning_rate=0.1;, score=0.921 total time=   1.0s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.918 total time=   1.0s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.921 total time=   1.0s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.01;, score=0.902 total time=   1.0s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.926 total time=   1.0s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.933 total time=   1.0s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.05;, score=0.914 total time=   1.0s
# [CV 1/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.927 total time=   0.9s
# [CV 2/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.936 total time=   1.7s
# [CV 3/3] END depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.1;, score=0.915 total time=   1.9s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.926 total time=   5.1s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.926 total time=   3.5s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.01;, score=0.902 total time=   3.7s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.930 total time=   6.4s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.930 total time=   4.7s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.05;, score=0.915 total time=   4.2s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.926 total time=   5.2s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.937 total time=   6.1s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=1, learning_rate=0.1;, score=0.917 total time=   4.1s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.922 total time=   3.5s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.926 total time=   6.0s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.01;, score=0.904 total time=   4.3s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.930 total time=   3.9s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.934 total time=   4.5s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.05;, score=0.921 total time=   6.6s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.929 total time=   4.1s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.937 total time=   4.0s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=3, learning_rate=0.1;, score=0.920 total time=   6.7s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.920 total time=   4.2s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.925 total time=   3.5s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.01;, score=0.902 total time=   3.7s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.927 total time=   6.7s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.932 total time=   3.9s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.05;, score=0.915 total time=   4.0s
# [CV 1/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.924 total time=   5.6s
# [CV 2/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.931 total time=   5.6s
# [CV 3/3] END depth=8, iterations=200, l2_leaf_reg=5, learning_rate=0.1;, score=0.911 total time=   4.2s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.927 total time=   7.0s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.930 total time=   7.2s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.01;, score=0.911 total time=   5.9s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.928 total time=   9.3s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.933 total time=   6.0s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.05;, score=0.913 total time=   9.4s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.923 total time=   6.1s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.934 total time=   8.1s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=1, learning_rate=0.1;, score=0.918 total time=   7.4s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.927 total time=   6.0s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.927 total time=   8.1s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.01;, score=0.909 total time=   5.6s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.926 total time=   9.0s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.937 total time=   6.1s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.05;, score=0.919 total time=   7.8s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.924 total time=   7.5s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.937 total time=   6.5s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=3, learning_rate=0.1;, score=0.917 total time=   8.9s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.923 total time=   5.6s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.927 total time=   8.6s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.01;, score=0.913 total time=   5.7s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.923 total time=   7.3s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.933 total time=   7.6s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.05;, score=0.918 total time=   6.3s
# [CV 1/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.925 total time=   9.3s
# [CV 2/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.930 total time=   6.1s
# [CV 3/3] END depth=8, iterations=300, l2_leaf_reg=5, learning_rate=0.1;, score=0.914 total time=   9.3s
# Meilleurs hyperparamèetres:
#    depth  iterations  l2_leaf_reg  learning_rate
# 0      8         200            3            0.1
#
# Meilleur score: 0.928614356318604

# %%
catb_acc = {}
catb_f1 = {}

# %% [markdown]
# Meilleur modèle CatB:

# %%
catbClassifier_optimized = grid_search.best_estimator_

# %% [markdown]
# ## Simplified + One hot

# %%
catb_acc["Simplified + OneHot"] =  None
catb_f1["Simplified + OneHot"] = None

# %% [markdown]
# ## Original + One hot

# %%
catb_acc["Original + OneHot"] = None
catb_f1["Original + OneHot"] = None

# %% [markdown]
# ## Simplified

# %%
catbClassifier_optimized.fit(X_train_simplified, y_train_simplified)
catbClassifier_optimized_acc = catbClassifier_optimized.score(X_test_simplified, y_test_simplified)
catbClassifier_optimized_predz = catbClassifier_optimized.predict(X_test_simplified)
catbClassifier_optimized_f1 = f1_score(y_test_simplified, catbClassifier_optimized_predz, average='binary')

catb_acc["Simplified"] = catbClassifier_optimized_acc
catb_f1["Simplified"] = catbClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
catb_acc["Original"] = None
catb_f1["Original"] = None

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["CatBoost"] = catb_acc
dict_f1["CatBoost"] = catb_f1

# %% [markdown]
# # Résultats

# %%
df_acc = pd.DataFrame(dict_accuracy)
df_acc
# Out:
#                       XGboost       SVC       KNN  CatBoost
# Simplified + OneHot  0.906336  0.916437  0.878788       NaN
# Original + OneHot    0.899908  0.912764  0.877870       NaN
# Simplified           0.910927  0.915519  0.864096  0.905418
# Original             0.913682  0.918274  0.845730       NaN

# %%
df_f1 = pd.DataFrame(dict_f1)
df_f1
# Out:
#                       XGboost       SVC       KNN  CatBoost
# Simplified + OneHot  0.927143  0.934954  0.908966       NaN
# Original + OneHot    0.922420  0.932288  0.908591       NaN
# Simplified           0.930764  0.934566  0.899183  0.926059
# Original             0.932665  0.936745  0.886792       NaN
