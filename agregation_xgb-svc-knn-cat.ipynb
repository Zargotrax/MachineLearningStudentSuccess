# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn import metrics
from sklearn.metrics import classification_report, f1_score
from catboost import CatBoostClassifier

from load_dataset import load_data

# %%
# load drive in Colab environment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Utils functions and global variables

# %%
# unused here but provides a non-optimized ready to use dataset
def load_data_nonOptimized():
  data = pd.read_csv("drive/MyDrive/data_ml_project_GIF4101/dataset.csv")

  # remove "Enrolled" target as it's not relevant to the project
  data = data[data['Target'] != "Enrolled"]

  # separating X from Y
  dataY = data.iloc[:,-1:]
  dataX = data.drop("Target", axis=1)

  # numpyification
  arrayX = pd.DataFrame.to_numpy(dataX)
  arrayY = pd.DataFrame.to_numpy(dataY)

  X_train, X_test, y_train, y_test = train_test_split(arrayX, arrayY, test_size=0.2, random_state=42)

  # transforming target labels to either 1 or 0
  le = LabelEncoder()
  y_train = le.fit_transform(y_train)
  y_test = le.fit_transform(y_test)

  return X_train, X_test, y_train, y_test

# %%
def get_max_from_dict(dict):
  max_value = 0
  for key, val in dict.items():
    if val > max_value:
      max_key = key
      max_value = val

  return (max_key, max_value)

# %%
dict_accuracy = {}
dict_f1 = {}

# %% [markdown]
# # Instancier jeux de données

# %% [markdown]
# Depuis la classe utilitaire load_dataset, instancier différentes versions du jeux de données. Les modèles seront testés sur la base des 4 jeux de données, ce qui permettra d'avoir une meilleure visibilité sur la pertinence des modifications de chaque versions en rapport à leurs résultats respectifs.
#
# Cela facilitera aussi la sélection des jeux de données à pousser plus loin en analyse des features.
#
# La variables cat_features_catb est surtout utile pour l'entraînement du CatBoost qui ne peux seulement consommer que la version Simplified du dataset.

# %%
X, y, cat_features = load_data().get_data_X_y(data='simplify', OneHot=True)
X_train_simplified_oneHot, X_test_simplified_oneHot, y_train_simplified_oneHot, y_test_simplified_oneHot = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X, y, cat_features = load_data().get_data_X_y(data='original', OneHot=True)
X_train_original_oneHot, X_test_original_oneHot, y_train_original_oneHot, y_test_original_oneHot = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X, y, cat_features_catb = load_data().get_data_X_y(data='simplify')
X_train_simplified, X_test_simplified, y_train_simplified, y_test_simplified = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X, y, cat_features = load_data().get_data_X_y(data='original')
X_train_original, X_test_original, y_train_original, y_test_original = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # XGboost

# %% [markdown]
# ## Recherche en grille

# %% [markdown]
# Le booster est, ici, nécessairement Gblinear. Les deux autre choix, en l'occurence Gbtree et Dart, prenaient un temps immense à être entrainés dans la recherche en grille. De plus, des tests hors recherche en grille ont prouvés à plusieurs reprises que Gblinear offre des meilleurs résultats d'accuracy et de score f1 sur nos données.
#
# Par mesure de simplicité et d'efficacité, le paramètre booster est donc défini par défaut sur Gblinear et la recherche en grille s'effectue sur la base des paramètres relatifs à un booster de type Gblinear.

# %%
# init xgb classifier
xgb_clf = xgb.XGBClassifier(verbosity=3, random_state=42)

param_grid = {
    'objective':["binary:logistic", "binary:hinge"],
    'booster':["gblinear"],
    'enable_categorical':[True],
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.05, 0.1],
}


# init grid search
grid_search = GridSearchCV(estimator=xgb_clf, param_grid=param_grid, cv=3, scoring='f1')

grid_search.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# [09:11:03] ======== Monitor (0): Learner ========
# [09:11:03] Configure: 0.000537s, 1 calls @ 537us
#
# [09:11:03] EvalOneIter: 0.000931s, 50 calls @ 931us
#
# [09:11:03] GetGradient: 1.83842s, 50 calls @ 1838416us
#
# [09:11:03] PredictRaw: 1.77716s, 50 calls @ 1777155us
#
# [09:11:03] UpdateOneIter: 9.15496s, 50 calls @ 9154956us
#
# [09:11:03] ======== Monitor (0): GBLinear ========
# [09:11:03] DoBoost: 5.48027s, 50 calls @ 5480275us
#
# [09:11:03] PredictBatch: 1.76916s, 50 calls @ 1769162us
#
# [09:11:03] PredictBatchInternal: 1.76909s, 50 calls @ 1769087us
#
# [09:11:10] ======== Monitor (0): Learner ========
# [09:11:10] Configure: 0.000203s, 1 calls @ 203us
#
# [09:11:10] EvalOneIter: 0.000722s, 50 calls @ 722us
#
# [09:11:10] GetGradient: 1.19464s, 50 calls @ 1194644us
#
# [09:11:10] PredictRaw: 1.2387s, 50 calls @ 1238696us
#
# [09:11:10] UpdateOneIter: 6.21s, 50 calls @ 6210005us
#
# [09:11:10] ======== Monitor (0): GBLinear ========
# [09:11:10] DoBoost: 3.71501s, 50 calls @ 3715012us
#
# [09:11:10] PredictBatch: 1.23857s, 50 calls @ 1238569us
#
# [09:11:10] PredictBatchInternal: 1.23845s, 50 calls @ 1238453us
#
# [09:11:15] ======== Monitor (0): Learner ========
# [09:11:15] Configure: 0.00021s, 1 calls @ 210us
#
# [09:11:15] EvalOneIter: 0.000806s, 50 calls @ 806us
#
# [09:11:15] GetGradient: 0.882975s, 50 calls @ 882975us
#
# [09:11:15] PredictRaw: 0.864074s, 50 calls @ 864074us
#
# [09:11:15] UpdateOneIter: 4.58159s, 50 calls @ 4581592us
#
# [09:11:15] ======== Monitor (0): GBLinear ========
# [09:11:15] DoBoost: 2.75258s, 50 calls @ 2752582us
#
# [09:11:15] PredictBatch: 0.863938s, 50 calls @ 863938us
#
# [09:11:15] PredictBatchInternal: 0.863852s, 50 calls @ 863852us
#
# [09:11:22] ======== Monitor (0): Learner ========
# [09:11:22] Configure: 0.0002s, 1 calls @ 200us
#
# [09:11:22] EvalOneIter: 0.000967s, 50 calls @ 967us
#
# [09:11:22] GetGradient: 1.27287s, 50 calls @ 1272875us
#
# [09:11:22] PredictRaw: 1.26514s, 50 calls @ 1265139us
#
# [09:11:22] UpdateOneIter: 6.56564s, 50 calls @ 6565645us
#
# [09:11:22] ======== Monitor (0): GBLinear ========
# [09:11:22] DoBoost: 4.02673s, 50 calls @ 4026733us
#
# [09:11:22] PredictBatch: 1.26502s, 50 calls @ 1265024us
#
# [09:11:22] PredictBatchInternal: 1.26495s, 50 calls @ 1264947us
#
# [09:11:32] ======== Monitor (0): Learner ========
# [09:11:32] Configure: 0.000203s, 1 calls @ 203us
#
# [09:11:32] EvalOneIter: 0.000635s, 50 calls @ 635us
#
# [09:11:32] GetGradient: 1.8392s, 50 calls @ 1839198us
#
# [09:11:32] PredictRaw: 1.82232s, 50 calls @ 1822321us
#
# [09:11:32] UpdateOneIter: 9.45979s, 50 calls @ 9459788us
#
# [09:11:32] ======== Monitor (0): GBLinear ========
# [09:11:32] DoBoost: 5.79759s, 50 calls @ 5797592us
#
# [09:11:32] PredictBatch: 1.82221s, 50 calls @ 1822207us
#
# [09:11:32] PredictBatchInternal: 1.82213s, 50 calls @ 1822128us
#
# [09:11:37] ======== Monitor (0): Learner ========
# [09:11:37] Configure: 0.000193s, 1 calls @ 193us
#
# [09:11:37] EvalOneIter: 0.001087s, 50 calls @ 1087us
#
# [09:11:37] GetGradient: 0.979314s, 50 calls @ 979314us
#
# [09:11:37] PredictRaw: 0.945785s, 50 calls @ 945785us
#
# [09:11:37] UpdateOneIter: 5.00095s, 50 calls @ 5000946us
#
# [09:11:37] ======== Monitor (0): GBLinear ========
# [09:11:37] DoBoost: 3.07518s, 50 calls @ 3075179us
#
# [09:11:37] PredictBatch: 0.94562s, 50 calls @ 945620us
#
# [09:11:37] PredictBatchInternal: 0.945537s, 50 calls @ 945537us
#
# [09:11:57] ======== Monitor (0): Learner ========
# [09:11:57] Configure: 0.000668s, 1 calls @ 668us
#
# [09:11:57] EvalOneIter: 0.00257s, 100 calls @ 2570us
#
# [09:11:57] GetGradient: 3.74711s, 100 calls @ 3747108us
#
# [09:11:57] PredictRaw: 3.7864s, 100 calls @ 3786403us
#
# [09:11:57] UpdateOneIter: 18.9922s, 100 calls @ 18992249us
#
# [09:11:57] ======== Monitor (0): GBLinear ========
# [09:11:57] DoBoost: 11.373s, 100 calls @ 11373013us
#
# [09:11:57] PredictBatch: 3.78621s, 100 calls @ 3786213us
#
# [09:11:57] PredictBatchInternal: 3.78608s, 100 calls @ 3786076us
#
# [09:12:14] ======== Monitor (0): Learner ========
# [09:12:14] Configure: 0.000222s, 1 calls @ 222us
#
# [09:12:14] EvalOneIter: 0.001611s, 100 calls @ 1611us
#
# [09:12:14] GetGradient: 3.36891s, 100 calls @ 3368906us
#
# [09:12:14] PredictRaw: 3.48342s, 100 calls @ 3483425us
#
# [09:12:14] UpdateOneIter: 17.1444s, 100 calls @ 17144360us
#
# [09:12:14] ======== Monitor (0): GBLinear ========
# [09:12:14] DoBoost: 10.1834s, 100 calls @ 10183414us
#
# [09:12:14] PredictBatch: 3.4832s, 100 calls @ 3483200us
#
# [09:12:14] PredictBatchInternal: 3.48303s, 100 calls @ 3483032us
#
# [09:12:33] ======== Monitor (0): Learner ========
# [09:12:33] Configure: 0.000254s, 1 calls @ 254us
#
# [09:12:33] EvalOneIter: 0.0013s, 100 calls @ 1300us
#
# [09:12:33] GetGradient: 3.65414s, 100 calls @ 3654138us
#
# [09:12:33] PredictRaw: 3.71545s, 100 calls @ 3715452us
#
# [09:12:33] UpdateOneIter: 18.7352s, 100 calls @ 18735180us
#
# [09:12:33] ======== Monitor (0): GBLinear ========
# [09:12:33] DoBoost: 11.2692s, 100 calls @ 11269216us
#
# [09:12:33] PredictBatch: 3.71524s, 100 calls @ 3715243us
#
# [09:12:33] PredictBatchInternal: 3.71508s, 100 calls @ 3715079us
#
# [09:12:52] ======== Monitor (0): Learner ========
# [09:12:52] Configure: 0.000226s, 1 calls @ 226us
#
# [09:12:52] EvalOneIter: 0.00655s, 100 calls @ 6550us
#
# [09:12:52] GetGradient: 3.70547s, 100 calls @ 3705471us
#
# [09:12:52] PredictRaw: 3.64665s, 100 calls @ 3646646us
#
# [09:12:52] UpdateOneIter: 18.5506s, 100 calls @ 18550589us
#
# [09:12:52] ======== Monitor (0): GBLinear ========
# [09:12:52] DoBoost: 11.1972s, 100 calls @ 11197209us
#
# [09:12:52] PredictBatch: 3.64641s, 100 calls @ 3646414us
#
# [09:12:52] PredictBatchInternal: 3.64626s, 100 calls @ 3646258us
#
# [09:13:11] ======== Monitor (0): Learner ========
# [09:13:11] Configure: 0.000179s, 1 calls @ 179us
#
# [09:13:11] EvalOneIter: 0.001404s, 100 calls @ 1404us
#
# [09:13:11] GetGradient: 3.53521s, 100 calls @ 3535214us
#
# [09:13:11] PredictRaw: 3.5055s, 100 calls @ 3505499us
#
# [09:13:11] UpdateOneIter: 17.7867s, 100 calls @ 17786664us
#
# [09:13:11] ======== Monitor (0): GBLinear ========
# [09:13:11] DoBoost: 10.7449s, 100 calls @ 10744861us
#
# [09:13:11] PredictBatch: 3.50527s, 100 calls @ 3505266us
#
# [09:13:11] PredictBatchInternal: 3.50512s, 100 calls @ 3505123us
#
# [09:13:29] ======== Monitor (0): Learner ========
# [09:13:29] Configure: 0.000187s, 1 calls @ 187us
#
# [09:13:29] EvalOneIter: 0.003085s, 100 calls @ 3085us
#
# [09:13:29] GetGradient: 3.69536s, 100 calls @ 3695361us
#
# [09:13:29] PredictRaw: 3.52193s, 100 calls @ 3521929us
#
# [09:13:29] UpdateOneIter: 18.2025s, 100 calls @ 18202483us
#
# [09:13:29] ======== Monitor (0): GBLinear ========
# [09:13:29] DoBoost: 10.9839s, 100 calls @ 10983902us
#
# [09:13:29] PredictBatch: 3.52172s, 100 calls @ 3521717us
#
# [09:13:29] PredictBatchInternal: 3.5213s, 100 calls @ 3521304us
#
# [09:14:00] ======== Monitor (0): Learner ========
# [09:14:00] Configure: 0.000455s, 1 calls @ 455us
#
# [09:14:00] EvalOneIter: 0.002119s, 150 calls @ 2119us
#
# [09:14:00] GetGradient: 5.84087s, 150 calls @ 5840874us
#
# [09:14:00] PredictRaw: 5.74251s, 150 calls @ 5742506us
#
# [09:14:00] UpdateOneIter: 29.4001s, 150 calls @ 29400052us
#
# [09:14:00] ======== Monitor (0): GBLinear ========
# [09:14:00] DoBoost: 17.6798s, 150 calls @ 17679828us
#
# [09:14:00] PredictBatch: 5.74193s, 150 calls @ 5741929us
#
# [09:14:00] PredictBatchInternal: 5.74167s, 150 calls @ 5741671us
#
# [09:14:35] ======== Monitor (0): Learner ========
# [09:14:35] Configure: 0.000316s, 1 calls @ 316us
#
# [09:14:35] EvalOneIter: 0.002619s, 150 calls @ 2619us
#
# [09:14:35] GetGradient: 6.76204s, 150 calls @ 6762039us
#
# [09:14:35] PredictRaw: 6.93301s, 150 calls @ 6933006us
#
# [09:14:35] UpdateOneIter: 35.0086s, 150 calls @ 35008646us
#
# [09:14:35] ======== Monitor (0): GBLinear ========
# [09:14:35] DoBoost: 21.2159s, 150 calls @ 21215912us
#
# [09:14:35] PredictBatch: 6.93268s, 150 calls @ 6932683us
#
# [09:14:35] PredictBatchInternal: 6.93243s, 150 calls @ 6932433us
#
# [09:15:10] ======== Monitor (0): Learner ========
# [09:15:10] Configure: 0.000225s, 1 calls @ 225us
#
# [09:15:10] EvalOneIter: 0.006863s, 150 calls @ 6863us
#
# [09:15:10] GetGradient: 6.7946s, 150 calls @ 6794601us
#
# [09:15:10] PredictRaw: 6.66008s, 150 calls @ 6660080us
#
# [09:15:10] UpdateOneIter: 34.5792s, 150 calls @ 34579179us
#
# [09:15:10] ======== Monitor (0): GBLinear ========
# [09:15:10] DoBoost: 20.872s, 150 calls @ 20872035us
#
# [09:15:10] PredictBatch: 6.65934s, 150 calls @ 6659341us
#
# [09:15:10] PredictBatchInternal: 6.65883s, 150 calls @ 6658830us
#
# [09:15:42] ======== Monitor (0): Learner ========
# [09:15:42] Configure: 0.000212s, 1 calls @ 212us
#
# [09:15:42] EvalOneIter: 0.001997s, 150 calls @ 1997us
#
# [09:15:42] GetGradient: 6.19163s, 150 calls @ 6191634us
#
# [09:15:42] PredictRaw: 5.99075s, 150 calls @ 5990747us
#
# [09:15:42] UpdateOneIter: 30.6785s, 150 calls @ 30678485us
#
# [09:15:42] ======== Monitor (0): GBLinear ========
# [09:15:42] DoBoost: 18.4945s, 150 calls @ 18494536us
#
# [09:15:42] PredictBatch: 5.99045s, 150 calls @ 5990445us
#
# [09:15:42] PredictBatchInternal: 5.99023s, 150 calls @ 5990233us
#
# [09:16:11] ======== Monitor (0): Learner ========
# [09:16:11] Configure: 0.000195s, 1 calls @ 195us
#
# [09:16:11] EvalOneIter: 0.003716s, 150 calls @ 3716us
#
# [09:16:11] GetGradient: 5.6687s, 150 calls @ 5668702us
#
# [09:16:11] PredictRaw: 5.70505s, 150 calls @ 5705049us
#
# [09:16:11] UpdateOneIter: 28.3651s, 150 calls @ 28365069us
#
# [09:16:11] ======== Monitor (0): GBLinear ========
# [09:16:11] DoBoost: 16.9896s, 150 calls @ 16989584us
#
# [09:16:11] PredictBatch: 5.70474s, 150 calls @ 5704740us
#
# [09:16:11] PredictBatchInternal: 5.7045s, 150 calls @ 5704504us
#
# [09:16:36] ======== Monitor (0): Learner ========
# [09:16:36] Configure: 0.00021s, 1 calls @ 210us
#
# [09:16:36] EvalOneIter: 0.001964s, 150 calls @ 1964us
#
# [09:16:36] GetGradient: 4.80859s, 150 calls @ 4808587us
#
# [09:16:36] PredictRaw: 4.967s, 150 calls @ 4967002us
#
# [09:16:36] UpdateOneIter: 24.6676s, 150 calls @ 24667553us
#
# [09:16:36] ======== Monitor (0): GBLinear ========
# [09:16:36] DoBoost: 14.89s, 150 calls @ 14890048us
#
# [09:16:36] PredictBatch: 4.96669s, 150 calls @ 4966689us
#
# [09:16:36] PredictBatchInternal: 4.9664s, 150 calls @ 4966399us
#
# [09:16:44] ======== Monitor (0): Learner ========
# [09:16:44] Configure: 0.000206s, 1 calls @ 206us
#
# [09:16:44] EvalOneIter: 0.000862s, 50 calls @ 862us
#
# [09:16:44] GetGradient: 1.37928s, 50 calls @ 1379276us
#
# [09:16:44] PredictRaw: 1.58012s, 50 calls @ 1580116us
#
# [09:16:44] UpdateOneIter: 7.33101s, 50 calls @ 7331008us
#
# [09:16:44] ======== Monitor (0): GBLinear ========
# [09:16:44] DoBoost: 4.30555s, 50 calls @ 4305550us
#
# [09:16:44] PredictBatch: 1.58001s, 50 calls @ 1580013us
#
# [09:16:44] PredictBatchInternal: 1.57994s, 50 calls @ 1579941us
#
# [09:16:53] ======== Monitor (0): Learner ========
# [09:16:53] Configure: 0.000229s, 1 calls @ 229us
#
# [09:16:53] EvalOneIter: 0.00076s, 50 calls @ 760us
#
# [09:16:53] GetGradient: 1.82318s, 50 calls @ 1823177us
#
# [09:16:53] PredictRaw: 1.78688s, 50 calls @ 1786881us
#
# [09:16:53] UpdateOneIter: 9.20361s, 50 calls @ 9203609us
#
# [09:16:53] ======== Monitor (0): GBLinear ========
# [09:16:53] DoBoost: 5.5209s, 50 calls @ 5520896us
#
# [09:16:53] PredictBatch: 1.78676s, 50 calls @ 1786762us
#
# [09:16:53] PredictBatchInternal: 1.78668s, 50 calls @ 1786684us
#
# [09:17:05] ======== Monitor (0): Learner ========
# [09:17:05] Configure: 0.000206s, 1 calls @ 206us
#
# [09:17:05] EvalOneIter: 0.000638s, 50 calls @ 638us
#
# [09:17:05] GetGradient: 2.19701s, 50 calls @ 2197007us
#
# [09:17:05] PredictRaw: 2.01861s, 50 calls @ 2018614us
#
# [09:17:05] UpdateOneIter: 10.8165s, 50 calls @ 10816473us
#
# [09:17:05] ======== Monitor (0): GBLinear ========
# [09:17:05] DoBoost: 6.47649s, 50 calls @ 6476489us
#
# [09:17:05] PredictBatch: 2.01852s, 50 calls @ 2018518us
#
# [09:17:05] PredictBatchInternal: 2.01844s, 50 calls @ 2018445us
#
# [09:17:13] ======== Monitor (0): Learner ========
# [09:17:13] Configure: 0.000191s, 1 calls @ 191us
#
# [09:17:13] EvalOneIter: 0.000626s, 50 calls @ 626us
#
# [09:17:13] GetGradient: 1.41658s, 50 calls @ 1416576us
#
# [09:17:13] PredictRaw: 1.51456s, 50 calls @ 1514565us
#
# [09:17:13] UpdateOneIter: 7.41406s, 50 calls @ 7414056us
#
# [09:17:13] ======== Monitor (0): GBLinear ========
# [09:17:13] DoBoost: 4.48223s, 50 calls @ 4482226us
#
# [09:17:13] PredictBatch: 1.51445s, 50 calls @ 1514450us
#
# [09:17:13] PredictBatchInternal: 1.51411s, 50 calls @ 1514113us
#
# [09:17:20] ======== Monitor (0): Learner ========
# [09:17:20] Configure: 0.000235s, 1 calls @ 235us
#
# [09:17:20] EvalOneIter: 0.000677s, 50 calls @ 677us
#
# [09:17:20] GetGradient: 1.27014s, 50 calls @ 1270142us
#
# [09:17:20] PredictRaw: 1.53024s, 50 calls @ 1530240us
#
# [09:17:20] UpdateOneIter: 6.93398s, 50 calls @ 6933978us
#
# [09:17:20] ======== Monitor (0): GBLinear ========
# [09:17:20] DoBoost: 4.13219s, 50 calls @ 4132189us
#
# [09:17:20] PredictBatch: 1.5301s, 50 calls @ 1530102us
#
# [09:17:20] PredictBatchInternal: 1.52993s, 50 calls @ 1529933us
#
# [09:17:27] ======== Monitor (0): Learner ========
# [09:17:27] Configure: 0.000204s, 1 calls @ 204us
#
# [09:17:27] EvalOneIter: 0.000652s, 50 calls @ 652us
#
# [09:17:27] GetGradient: 1.36809s, 50 calls @ 1368092us
#
# [09:17:27] PredictRaw: 1.37275s, 50 calls @ 1372754us
#
# [09:17:27] UpdateOneIter: 6.83939s, 50 calls @ 6839393us
#
# [09:17:27] ======== Monitor (0): GBLinear ========
# [09:17:27] DoBoost: 4.09781s, 50 calls @ 4097806us
#
# [09:17:27] PredictBatch: 1.37266s, 50 calls @ 1372656us
#
# [09:17:27] PredictBatchInternal: 1.37257s, 50 calls @ 1372571us
#
# [09:17:44] ======== Monitor (0): Learner ========
# [09:17:44] Configure: 0.000213s, 1 calls @ 213us
#
# [09:17:44] EvalOneIter: 0.001661s, 100 calls @ 1661us
#
# [09:17:44] GetGradient: 3.12186s, 100 calls @ 3121862us
#
# [09:17:44] PredictRaw: 3.16756s, 100 calls @ 3167558us
#
# [09:17:44] UpdateOneIter: 15.8688s, 100 calls @ 15868821us
#
# [09:17:44] ======== Monitor (0): GBLinear ========
# [09:17:44] DoBoost: 9.50924s, 100 calls @ 9509243us
#
# [09:17:44] PredictBatch: 3.16733s, 100 calls @ 3167333us
#
# [09:17:44] PredictBatchInternal: 3.16708s, 100 calls @ 3167075us
#
# [09:18:04] ======== Monitor (0): Learner ========
# [09:18:04] Configure: 0.000202s, 1 calls @ 202us
#
# [09:18:04] EvalOneIter: 0.006131s, 100 calls @ 6131us
#
# [09:18:04] GetGradient: 4.00025s, 100 calls @ 4000252us
#
# [09:18:04] PredictRaw: 3.82116s, 100 calls @ 3821159us
#
# [09:18:04] UpdateOneIter: 19.6975s, 100 calls @ 19697521us
#
# [09:18:04] ======== Monitor (0): GBLinear ========
# [09:18:04] DoBoost: 11.8038s, 100 calls @ 11803762us
#
# [09:18:04] PredictBatch: 3.82093s, 100 calls @ 3820930us
#
# [09:18:04] PredictBatchInternal: 3.82078s, 100 calls @ 3820776us
#
# [09:18:18] ======== Monitor (0): Learner ========
# [09:18:18] Configure: 0.00029s, 1 calls @ 290us
#
# [09:18:18] EvalOneIter: 0.00145s, 100 calls @ 1450us
#
# [09:18:18] GetGradient: 2.60068s, 100 calls @ 2600680us
#
# [09:18:18] PredictRaw: 2.37527s, 100 calls @ 2375267us
#
# [09:18:18] UpdateOneIter: 12.8023s, 100 calls @ 12802283us
#
# [09:18:18] ======== Monitor (0): GBLinear ========
# [09:18:18] DoBoost: 7.75653s, 100 calls @ 7756533us
#
# [09:18:18] PredictBatch: 2.37505s, 100 calls @ 2375048us
#
# [09:18:18] PredictBatchInternal: 2.37488s, 100 calls @ 2374878us
#
# [09:18:22] ======== Monitor (0): Learner ========
# [09:18:22] Configure: 0.000211s, 1 calls @ 211us
#
# [09:18:22] EvalOneIter: 0.001244s, 100 calls @ 1244us
#
# [09:18:22] GetGradient: 0.809298s, 100 calls @ 809298us
#
# [09:18:22] PredictRaw: 0.810593s, 100 calls @ 810593us
#
# [09:18:22] UpdateOneIter: 3.86248s, 100 calls @ 3862482us
#
# [09:18:22] ======== Monitor (0): GBLinear ========
# [09:18:22] DoBoost: 2.24085s, 100 calls @ 2240849us
#
# [09:18:22] PredictBatch: 0.810391s, 100 calls @ 810391us
#
# [09:18:22] PredictBatchInternal: 0.810258s, 100 calls @ 810258us
#
# [09:18:23] ======== Monitor (0): Learner ========
# [09:18:23] Configure: 0.000262s, 1 calls @ 262us
#
# [09:18:23] EvalOneIter: 0.001724s, 100 calls @ 1724us
#
# [09:18:23] GetGradient: 0.08598s, 100 calls @ 85980us
#
# [09:18:23] PredictRaw: 0.122679s, 100 calls @ 122679us
#
# [09:18:23] UpdateOneIter: 0.420698s, 100 calls @ 420698us
#
# [09:18:23] ======== Monitor (0): GBLinear ========
# [09:18:23] DoBoost: 0.210984s, 100 calls @ 210984us
#
# [09:18:23] PredictBatch: 0.122502s, 100 calls @ 122502us
#
# [09:18:23] PredictBatchInternal: 0.122353s, 100 calls @ 122353us
#
# [09:18:23] ======== Monitor (0): Learner ========
# [09:18:23] Configure: 0.000173s, 1 calls @ 173us
#
# [09:18:23] EvalOneIter: 0.0013s, 100 calls @ 1300us
#
# [09:18:23] GetGradient: 0.052183s, 100 calls @ 52183us
#
# [09:18:23] PredictRaw: 0.092639s, 100 calls @ 92639us
#
# [09:18:23] UpdateOneIter: 0.260892s, 100 calls @ 260892us
#
# [09:18:23] ======== Monitor (0): GBLinear ========
# [09:18:23] DoBoost: 0.115111s, 100 calls @ 115111us
#
# [09:18:23] PredictBatch: 0.092439s, 100 calls @ 92439us
#
# [09:18:23] PredictBatchInternal: 0.092308s, 100 calls @ 92308us
#
# [09:18:24] ======== Monitor (0): Learner ========
# [09:18:24] Configure: 0.000221s, 1 calls @ 221us
#
# [09:18:24] EvalOneIter: 0.002505s, 150 calls @ 2505us
#
# [09:18:24] GetGradient: 0.066101s, 150 calls @ 66101us
#
# [09:18:24] PredictRaw: 0.15939s, 150 calls @ 159390us
#
# [09:18:24] UpdateOneIter: 0.384019s, 150 calls @ 384019us
#
# [09:18:24] ======== Monitor (0): GBLinear ========
# [09:18:24] DoBoost: 0.15445s, 150 calls @ 154450us
#
# [09:18:24] PredictBatch: 0.159146s, 150 calls @ 159146us
#
# [09:18:24] PredictBatchInternal: 0.158921s, 150 calls @ 158921us
#
# [09:18:24] ======== Monitor (0): Learner ========
# [09:18:24] Configure: 0.000196s, 1 calls @ 196us
#
# [09:18:24] EvalOneIter: 0.001589s, 150 calls @ 1589us
#
# [09:18:24] GetGradient: 0.045687s, 150 calls @ 45687us
#
# [09:18:24] PredictRaw: 0.175089s, 150 calls @ 175089us
#
# [09:18:24] UpdateOneIter: 0.358323s, 150 calls @ 358323us
#
# [09:18:24] ======== Monitor (0): GBLinear ========
# [09:18:24] DoBoost: 0.136305s, 150 calls @ 136305us
#
# [09:18:24] PredictBatch: 0.174873s, 150 calls @ 174873us
#
# [09:18:24] PredictBatchInternal: 0.174708s, 150 calls @ 174708us
#
# [09:18:25] ======== Monitor (0): Learner ========
# [09:18:25] Configure: 0.000205s, 1 calls @ 205us
#
# [09:18:25] EvalOneIter: 0.001551s, 150 calls @ 1551us
#
# [09:18:25] GetGradient: 0.048203s, 150 calls @ 48203us
#
# [09:18:25] PredictRaw: 0.120107s, 150 calls @ 120107us
#
# [09:18:25] UpdateOneIter: 0.316151s, 150 calls @ 316151us
#
# [09:18:25] ======== Monitor (0): GBLinear ========
# [09:18:25] DoBoost: 0.138186s, 150 calls @ 138186us
#
# [09:18:25] PredictBatch: 0.119887s, 150 calls @ 119887us
#
# [09:18:25] PredictBatchInternal: 0.119713s, 150 calls @ 119713us
#
# [09:18:26] ======== Monitor (0): Learner ========
# [09:18:26] Configure: 0.000194s, 1 calls @ 194us
#
# [09:18:26] EvalOneIter: 0.001633s, 150 calls @ 1633us
#
# [09:18:26] GetGradient: 0.046392s, 150 calls @ 46392us
#
# [09:18:26] PredictRaw: 0.116801s, 150 calls @ 116801us
#
# [09:18:26] UpdateOneIter: 0.327933s, 150 calls @ 327933us
#
# [09:18:26] ======== Monitor (0): GBLinear ========
# [09:18:26] DoBoost: 0.163628s, 150 calls @ 163628us
#
# [09:18:26] PredictBatch: 0.116603s, 150 calls @ 116603us
#
# [09:18:26] PredictBatchInternal: 0.116444s, 150 calls @ 116444us
#
# [09:18:26] ======== Monitor (0): Learner ========
# [09:18:26] Configure: 0.00025s, 1 calls @ 250us
#
# [09:18:26] EvalOneIter: 0.001521s, 150 calls @ 1521us
#
# [09:18:26] GetGradient: 0.077944s, 150 calls @ 77944us
#
# [09:18:26] PredictRaw: 0.102014s, 150 calls @ 102014us
#
# [09:18:26] UpdateOneIter: 0.387212s, 150 calls @ 387212us
#
# [09:18:26] ======== Monitor (0): GBLinear ========
# [09:18:26] DoBoost: 0.206155s, 150 calls @ 206155us
#
# [09:18:26] PredictBatch: 0.101822s, 150 calls @ 101822us
#
# [09:18:26] PredictBatchInternal: 0.101667s, 150 calls @ 101667us
#
# [09:18:27] ======== Monitor (0): Learner ========
# [09:18:27] Configure: 0.000201s, 1 calls @ 201us
#
# [09:18:27] EvalOneIter: 0.001232s, 150 calls @ 1232us
#
# [09:18:27] GetGradient: 0.010034s, 150 calls @ 10034us
#
# [09:18:27] PredictRaw: 0.026733s, 150 calls @ 26733us
#
# [09:18:27] UpdateOneIter: 0.117926s, 150 calls @ 117926us
#
# [09:18:27] ======== Monitor (0): GBLinear ========
# [09:18:27] DoBoost: 0.080232s, 150 calls @ 80232us
#
# [09:18:27] PredictBatch: 0.026579s, 150 calls @ 26579us
#
# [09:18:27] PredictBatchInternal: 0.026441s, 150 calls @ 26441us
#
# [09:18:27] ======== Monitor (0): Learner ========
# [09:18:27] Configure: 0.000186s, 1 calls @ 186us
#
# [09:18:27] EvalOneIter: 0.000362s, 50 calls @ 362us
#
# [09:18:27] GetGradient: 0.003434s, 50 calls @ 3434us
#
# [09:18:27] PredictRaw: 0.006982s, 50 calls @ 6982us
#
# [09:18:27] UpdateOneIter: 0.037165s, 50 calls @ 37165us
#
# [09:18:27] ======== Monitor (0): GBLinear ========
# [09:18:27] DoBoost: 0.023662s, 50 calls @ 23662us
#
# [09:18:27] PredictBatch: 0.006924s, 50 calls @ 6924us
#
# [09:18:27] PredictBatchInternal: 0.006884s, 50 calls @ 6884us
#
# [09:18:27] ======== Monitor (0): Learner ========
# [09:18:27] Configure: 0.000187s, 1 calls @ 187us
#
# [09:18:27] EvalOneIter: 0.000404s, 50 calls @ 404us
#
# [09:18:27] GetGradient: 0.01007s, 50 calls @ 10070us
#
# [09:18:27] PredictRaw: 0.016119s, 50 calls @ 16119us
#
# [09:18:27] UpdateOneIter: 0.053067s, 50 calls @ 53067us
#
# [09:18:27] ======== Monitor (0): GBLinear ========
# [09:18:27] DoBoost: 0.026388s, 50 calls @ 26388us
#
# [09:18:27] PredictBatch: 0.016052s, 50 calls @ 16052us
#
# [09:18:27] PredictBatchInternal: 0.015994s, 50 calls @ 15994us
#
# [09:18:27] ======== Monitor (0): Learner ========
# [09:18:27] Configure: 0.000183s, 1 calls @ 183us
#
# [09:18:27] EvalOneIter: 0.000364s, 50 calls @ 364us
#
# [09:18:27] GetGradient: 0.004033s, 50 calls @ 4033us
#
# [09:18:27] PredictRaw: 0.012417s, 50 calls @ 12417us
#
# [09:18:27] UpdateOneIter: 0.042586s, 50 calls @ 42586us
#
# [09:18:27] ======== Monitor (0): GBLinear ========
# [09:18:27] DoBoost: 0.025673s, 50 calls @ 25673us
#
# [09:18:27] PredictBatch: 0.012364s, 50 calls @ 12364us
#
# [09:18:27] PredictBatchInternal: 0.012319s, 50 calls @ 12319us
#
# [09:18:27] ======== Monitor (0): Learner ========
# [09:18:27] Configure: 0.000167s, 1 calls @ 167us
#
# [09:18:27] EvalOneIter: 0.000366s, 50 calls @ 366us
#
# [09:18:27] GetGradient: 0.011231s, 50 calls @ 11231us
#
# [09:18:27] PredictRaw: 0.018546s, 50 calls @ 18546us
#
# [09:18:27] UpdateOneIter: 0.056834s, 50 calls @ 56834us
#
# [09:18:27] ======== Monitor (0): GBLinear ========
# [09:18:27] DoBoost: 0.026665s, 50 calls @ 26665us
#
# [09:18:27] PredictBatch: 0.018495s, 50 calls @ 18495us
#
# [09:18:27] PredictBatchInternal: 0.018448s, 50 calls @ 18448us
#
# [09:18:27] ======== Monitor (0): Learner ========
# [09:18:27] Configure: 0.000182s, 1 calls @ 182us
#
# [09:18:27] EvalOneIter: 0.000412s, 50 calls @ 412us
#
# [09:18:27] GetGradient: 0.001685s, 50 calls @ 1685us
#
# [09:18:27] PredictRaw: 0.005399s, 50 calls @ 5399us
#
# [09:18:27] UpdateOneIter: 0.033711s, 50 calls @ 33711us
#
# [09:18:27] ======== Monitor (0): GBLinear ========
# [09:18:27] DoBoost: 0.026197s, 50 calls @ 26197us
#
# [09:18:27] PredictBatch: 0.005344s, 50 calls @ 5344us
#
# [09:18:27] PredictBatchInternal: 0.005303s, 50 calls @ 5303us
#
# [09:18:28] ======== Monitor (0): Learner ========
# [09:18:28] Configure: 0.000205s, 1 calls @ 205us
#
# [09:18:28] EvalOneIter: 0.000509s, 50 calls @ 509us
#
# [09:18:28] GetGradient: 0.00176s, 50 calls @ 1760us
#
# [09:18:28] PredictRaw: 0.006117s, 50 calls @ 6117us
#
# [09:18:28] UpdateOneIter: 0.036378s, 50 calls @ 36378us
#
# [09:18:28] ======== Monitor (0): GBLinear ========
# [09:18:28] DoBoost: 0.028005s, 50 calls @ 28005us
#
# [09:18:28] PredictBatch: 0.006053s, 50 calls @ 6053us
#
# [09:18:28] PredictBatchInternal: 0.006003s, 50 calls @ 6003us
#
# [09:18:28] ======== Monitor (0): Learner ========
# [09:18:28] Configure: 0.000194s, 1 calls @ 194us
#
# [09:18:28] EvalOneIter: 0.000832s, 100 calls @ 832us
#
# [09:18:28] GetGradient: 0.003217s, 100 calls @ 3217us
#
# [09:18:28] PredictRaw: 0.010281s, 100 calls @ 10281us
#
# [09:18:28] UpdateOneIter: 0.058631s, 100 calls @ 58631us
#
# [09:18:28] ======== Monitor (0): GBLinear ========
# [09:18:28] DoBoost: 0.044387s, 100 calls @ 44387us
#
# [09:18:28] PredictBatch: 0.010179s, 100 calls @ 10179us
#
# [09:18:28] PredictBatchInternal: 0.010097s, 100 calls @ 10097us
#
# [09:18:28] ======== Monitor (0): Learner ========
# [09:18:28] Configure: 0.000197s, 1 calls @ 197us
#
# [09:18:28] EvalOneIter: 0.000847s, 100 calls @ 847us
#
# [09:18:28] GetGradient: 0.005948s, 100 calls @ 5948us
#
# [09:18:28] PredictRaw: 0.019937s, 100 calls @ 19937us
#
# [09:18:28] UpdateOneIter: 0.071396s, 100 calls @ 71396us
#
# [09:18:28] ======== Monitor (0): GBLinear ========
# [09:18:28] DoBoost: 0.044729s, 100 calls @ 44729us
#
# [09:18:28] PredictBatch: 0.019818s, 100 calls @ 19818us
#
# [09:18:28] PredictBatchInternal: 0.019729s, 100 calls @ 19729us
#
# [09:18:28] ======== Monitor (0): Learner ========
# [09:18:28] Configure: 0.000199s, 1 calls @ 199us
#
# [09:18:28] EvalOneIter: 0.000768s, 100 calls @ 768us
#
# [09:18:28] GetGradient: 0.002554s, 100 calls @ 2554us
#
# [09:18:28] PredictRaw: 0.012533s, 100 calls @ 12533us
#
# [09:18:28] UpdateOneIter: 0.062627s, 100 calls @ 62627us
#
# [09:18:28] ======== Monitor (0): GBLinear ========
# [09:18:28] DoBoost: 0.046781s, 100 calls @ 46781us
#
# [09:18:28] PredictBatch: 0.012434s, 100 calls @ 12434us
#
# [09:18:28] PredictBatchInternal: 0.01235s, 100 calls @ 12350us
#
# [09:18:29] ======== Monitor (0): Learner ========
# [09:18:29] Configure: 0.000234s, 1 calls @ 234us
#
# [09:18:29] EvalOneIter: 0.000979s, 100 calls @ 979us
#
# [09:18:29] GetGradient: 0.01273s, 100 calls @ 12730us
#
# [09:18:29] PredictRaw: 0.024914s, 100 calls @ 24914us
#
# [09:18:29] UpdateOneIter: 0.094163s, 100 calls @ 94163us
#
# [09:18:29] ======== Monitor (0): GBLinear ========
# [09:18:29] DoBoost: 0.055509s, 100 calls @ 55509us
#
# [09:18:29] PredictBatch: 0.024781s, 100 calls @ 24781us
#
# [09:18:29] PredictBatchInternal: 0.024681s, 100 calls @ 24681us
#
# [09:18:29] ======== Monitor (0): Learner ========
# [09:18:29] Configure: 0.000279s, 1 calls @ 279us
#
# [09:18:29] EvalOneIter: 0.000826s, 100 calls @ 826us
#
# [09:18:29] GetGradient: 0.005117s, 100 calls @ 5117us
#
# [09:18:29] PredictRaw: 0.01337s, 100 calls @ 13370us
#
# [09:18:29] UpdateOneIter: 0.068922s, 100 calls @ 68922us
#
# [09:18:29] ======== Monitor (0): GBLinear ========
# [09:18:29] DoBoost: 0.049621s, 100 calls @ 49621us
#
# [09:18:29] PredictBatch: 0.013262s, 100 calls @ 13262us
#
# [09:18:29] PredictBatchInternal: 0.013177s, 100 calls @ 13177us
#
# [09:18:29] ======== Monitor (0): Learner ========
# [09:18:29] Configure: 0.000192s, 1 calls @ 192us
#
# [09:18:29] EvalOneIter: 0.000783s, 100 calls @ 783us
#
# [09:18:29] GetGradient: 0.005488s, 100 calls @ 5488us
#
# [09:18:29] PredictRaw: 0.015028s, 100 calls @ 15028us
#
# [09:18:29] UpdateOneIter: 0.11288s, 100 calls @ 112880us
#
# [09:18:29] ======== Monitor (0): GBLinear ========
# [09:18:29] DoBoost: 0.091654s, 100 calls @ 91654us
#
# [09:18:29] PredictBatch: 0.014923s, 100 calls @ 14923us
#
# [09:18:29] PredictBatchInternal: 0.014845s, 100 calls @ 14845us
#
# [09:18:30] ======== Monitor (0): Learner ========
# [09:18:30] Configure: 0.000182s, 1 calls @ 182us
#
# [09:18:30] EvalOneIter: 0.001168s, 150 calls @ 1168us
#
# [09:18:30] GetGradient: 0.003556s, 150 calls @ 3556us
#
# [09:18:30] PredictRaw: 0.014844s, 150 calls @ 14844us
#
# [09:18:30] UpdateOneIter: 0.087006s, 150 calls @ 87006us
#
# [09:18:30] ======== Monitor (0): GBLinear ========
# [09:18:30] DoBoost: 0.067666s, 150 calls @ 67666us
#
# [09:18:30] PredictBatch: 0.014687s, 150 calls @ 14687us
#
# [09:18:30] PredictBatchInternal: 0.014567s, 150 calls @ 14567us
#
# [09:18:30] ======== Monitor (0): Learner ========
# [09:18:30] Configure: 0.000261s, 1 calls @ 261us
#
# [09:18:30] EvalOneIter: 0.001199s, 150 calls @ 1199us
#
# [09:18:30] GetGradient: 0.005323s, 150 calls @ 5323us
#
# [09:18:30] PredictRaw: 0.019173s, 150 calls @ 19173us
#
# [09:18:30] UpdateOneIter: 0.088458s, 150 calls @ 88458us
#
# [09:18:30] ======== Monitor (0): GBLinear ========
# [09:18:30] DoBoost: 0.062874s, 150 calls @ 62874us
#
# [09:18:30] PredictBatch: 0.019007s, 150 calls @ 19007us
#
# [09:18:30] PredictBatchInternal: 0.018865s, 150 calls @ 18865us
#
# [09:18:30] ======== Monitor (0): Learner ========
# [09:18:30] Configure: 0.000193s, 1 calls @ 193us
#
# [09:18:30] EvalOneIter: 0.001233s, 150 calls @ 1233us
#
# [09:18:30] GetGradient: 0.005187s, 150 calls @ 5187us
#
# [09:18:30] PredictRaw: 0.018815s, 150 calls @ 18815us
#
# [09:18:30] UpdateOneIter: 0.097384s, 150 calls @ 97384us
#
# [09:18:30] ======== Monitor (0): GBLinear ========
# [09:18:30] DoBoost: 0.072367s, 150 calls @ 72367us
#
# [09:18:30] PredictBatch: 0.018652s, 150 calls @ 18652us
#
# [09:18:30] PredictBatchInternal: 0.018517s, 150 calls @ 18517us
#
# [09:18:31] ======== Monitor (0): Learner ========
# [09:18:31] Configure: 0.000186s, 1 calls @ 186us
#
# [09:18:31] EvalOneIter: 0.00119s, 150 calls @ 1190us
#
# [09:18:31] GetGradient: 0.005929s, 150 calls @ 5929us
#
# [09:18:31] PredictRaw: 0.017322s, 150 calls @ 17322us
#
# [09:18:31] UpdateOneIter: 0.097674s, 150 calls @ 97674us
#
# [09:18:31] ======== Monitor (0): GBLinear ========
# [09:18:31] DoBoost: 0.073479s, 150 calls @ 73479us
#
# [09:18:31] PredictBatch: 0.017157s, 150 calls @ 17157us
#
# [09:18:31] PredictBatchInternal: 0.017026s, 150 calls @ 17026us
#
# [09:18:31] ======== Monitor (0): Learner ========
# [09:18:31] Configure: 0.000246s, 1 calls @ 246us
#
# [09:18:31] EvalOneIter: 0.001323s, 150 calls @ 1323us
#
# [09:18:31] GetGradient: 0.006062s, 150 calls @ 6062us
#
# [09:18:31] PredictRaw: 0.018315s, 150 calls @ 18315us
#
# [09:18:31] UpdateOneIter: 0.096633s, 150 calls @ 96633us
#
# [09:18:31] ======== Monitor (0): GBLinear ========
# [09:18:31] DoBoost: 0.071173s, 150 calls @ 71173us
#
# [09:18:31] PredictBatch: 0.018137s, 150 calls @ 18137us
#
# [09:18:31] PredictBatchInternal: 0.017992s, 150 calls @ 17992us
#
# [09:18:31] ======== Monitor (0): Learner ========
# [09:18:31] Configure: 0.000172s, 1 calls @ 172us
#
# [09:18:31] EvalOneIter: 0.001155s, 150 calls @ 1155us
#
# [09:18:31] GetGradient: 0.006138s, 150 calls @ 6138us
#
# [09:18:31] PredictRaw: 0.015392s, 150 calls @ 15392us
#
# [09:18:31] UpdateOneIter: 0.095149s, 150 calls @ 95149us
#
# [09:18:31] ======== Monitor (0): GBLinear ========
# [09:18:31] DoBoost: 0.072713s, 150 calls @ 72713us
#
# [09:18:31] PredictBatch: 0.015232s, 150 calls @ 15232us
#
# [09:18:31] PredictBatchInternal: 0.015097s, 150 calls @ 15097us
#
# [09:18:32] ======== Monitor (0): Learner ========
# [09:18:32] Configure: 0.000183s, 1 calls @ 183us
#
# [09:18:32] EvalOneIter: 0.001421s, 150 calls @ 1421us
#
# [09:18:32] GetGradient: 0.006648s, 150 calls @ 6648us
#
# [09:18:32] PredictRaw: 0.027956s, 150 calls @ 27956us
#
# [09:18:32] UpdateOneIter: 0.158879s, 150 calls @ 158879us
#
# [09:18:32] ======== Monitor (0): GBLinear ========
# [09:18:32] DoBoost: 0.123277s, 150 calls @ 123277us
#
# [09:18:32] PredictBatch: 0.027781s, 150 calls @ 27781us
#
# [09:18:32] PredictBatchInternal: 0.027642s, 150 calls @ 27642us
#
# Meilleurs hyperparamèetres:
#     booster  enable_categorical  learning_rate  n_estimators     objective
# 0  gblinear                True            0.1           150  binary:hinge
#
# Meilleur score: 0.9178185722967837

# %%
xgb_acc = {}
xgb_f1 = {}

# %% [markdown]
# Meilleur modèle XGBoost:

# %%
xgbClassifier_optimized = xgb.XGBClassifier(**best_parameters, random_state=42)

# %% [markdown]
# ## Simplified + One hot

# %%
xgbClassifier_optimized.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_simplified_oneHot, y_test_simplified_oneHot)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_simplified_oneHot)
xgbClassifier_optimized_f1 = f1_score(y_test_simplified_oneHot, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Simplified + OneHot"] = xgbClassifier_optimized_acc
xgb_f1["Simplified + OneHot"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Original + One hot

# %%
xgbClassifier_optimized.fit(X_train_original_oneHot, y_train_original_oneHot)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_original_oneHot, y_test_original_oneHot)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_original_oneHot)
xgbClassifier_optimized_f1 = f1_score(y_test_original_oneHot, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Original + OneHot"] = xgbClassifier_optimized_acc
xgb_f1["Original + OneHot"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Simplified

# %%
xgbClassifier_optimized.fit(X_train_simplified, y_train_simplified)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_simplified, y_test_simplified)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_simplified)
xgbClassifier_optimized_f1 = f1_score(y_test_simplified, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Simplified"] = xgbClassifier_optimized_acc
xgb_f1["Simplified"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
xgbClassifier_optimized.fit(X_train_original, y_train_original)
xgbClassifier_optimized_acc = xgbClassifier_optimized.score(X_test_original, y_test_original)
xgbClassifier_optimized_predz = xgbClassifier_optimized.predict(X_test_original)
xgbClassifier_optimized_f1 = f1_score(y_test_original, xgbClassifier_optimized_predz, average='binary')

xgb_acc["Original"] = xgbClassifier_optimized_acc
xgb_f1["Original"] = xgbClassifier_optimized_f1

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["XGboost"] = xgb_acc
dict_f1["XGboost"] = xgb_f1

# %% [markdown]
# # SVC

# %% [markdown]
# ## Recherche en grille

# %% [markdown]
# Pour le SVC, le choix du kernel doit obligatoirement être linéaire, puisque cela empêche au modèle d'augmenter la dimensionnalité des données, ce qui nous empêcherait plus tard de faire une analyse claire des features les plus prenants pour la classification.
#
# L'utilisation d'un noyeau linéaire permet au SVM de rester dans l'espace dimensionnel de base et ne projète pas les features dans un espace à plus haute dimensionnalité, comme le ferait un noyeau Gaussien ou RBF, par exemple. C'est pourquoi nous pourrons directement récupérer l'importance des features plus tard dans l'analyse.

# %%
# by default SVC
svcClassifier = SVC(kernel="rbf", C=1.0, degree=3, gamma='scale', random_state=42)

param_grid = {
    'kernel': ['linear'],
    'C': [0.1, 1, 10, 50],
    'gamma': ['scale', 0.001, 0.1, 1],
    'class_weight': [None, 'balanced']
}

# init grid search
grid_search = GridSearchCV(estimator=svcClassifier, param_grid=param_grid, cv=3, scoring='f1', verbose=3)

grid_search.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV 1/3] END C=0.1, class_weight=None, gamma=scale, kernel=linear;, score=0.929 total time=   0.1s
# [CV 2/3] END C=0.1, class_weight=None, gamma=scale, kernel=linear;, score=0.932 total time=   0.1s
# [CV 3/3] END C=0.1, class_weight=None, gamma=scale, kernel=linear;, score=0.923 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=None, gamma=0.001, kernel=linear;, score=0.929 total time=   0.1s
# [CV 2/3] END C=0.1, class_weight=None, gamma=0.001, kernel=linear;, score=0.932 total time=   0.2s
# [CV 3/3] END C=0.1, class_weight=None, gamma=0.001, kernel=linear;, score=0.923 total time=   0.1s
# [CV 1/3] END C=0.1, class_weight=None, gamma=0.1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 2/3] END C=0.1, class_weight=None, gamma=0.1, kernel=linear;, score=0.932 total time=   0.1s
# [CV 3/3] END C=0.1, class_weight=None, gamma=0.1, kernel=linear;, score=0.923 total time=   0.2s
# [CV 1/3] END C=0.1, class_weight=None, gamma=1, kernel=linear;, score=0.929 total time=   0.1s
# [CV 2/3] END C=0.1, class_weight=None, gamma=1, kernel=linear;, score=0.932 total time=   0.1s
# [CV 3/3] END C=0.1, class_weight=None, gamma=1, kernel=linear;, score=0.923 total time=   0.1s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.925 total time=   0.1s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.923 total time=   0.1s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.912 total time=   0.1s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.925 total time=   0.1s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.923 total time=   0.1s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.925 total time=   0.0s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.923 total time=   0.0s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/3] END C=0.1, class_weight=balanced, gamma=1, kernel=linear;, score=0.925 total time=   0.0s
# [CV 2/3] END C=0.1, class_weight=balanced, gamma=1, kernel=linear;, score=0.923 total time=   0.0s
# [CV 3/3] END C=0.1, class_weight=balanced, gamma=1, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/3] END C=1, class_weight=None, gamma=scale, kernel=linear;, score=0.923 total time=   0.2s
# [CV 2/3] END C=1, class_weight=None, gamma=scale, kernel=linear;, score=0.925 total time=   0.3s
# [CV 3/3] END C=1, class_weight=None, gamma=scale, kernel=linear;, score=0.921 total time=   0.2s
# [CV 1/3] END C=1, class_weight=None, gamma=0.001, kernel=linear;, score=0.923 total time=   0.4s
# [CV 2/3] END C=1, class_weight=None, gamma=0.001, kernel=linear;, score=0.925 total time=   0.7s
# [CV 3/3] END C=1, class_weight=None, gamma=0.001, kernel=linear;, score=0.921 total time=   0.5s
# [CV 1/3] END C=1, class_weight=None, gamma=0.1, kernel=linear;, score=0.923 total time=   0.5s
# [CV 2/3] END C=1, class_weight=None, gamma=0.1, kernel=linear;, score=0.925 total time=   0.7s
# [CV 3/3] END C=1, class_weight=None, gamma=0.1, kernel=linear;, score=0.921 total time=   0.5s
# [CV 1/3] END C=1, class_weight=None, gamma=1, kernel=linear;, score=0.923 total time=   0.5s
# [CV 2/3] END C=1, class_weight=None, gamma=1, kernel=linear;, score=0.925 total time=   0.8s
# [CV 3/3] END C=1, class_weight=None, gamma=1, kernel=linear;, score=0.921 total time=   0.5s
# [CV 1/3] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.922 total time=   0.6s
# [CV 2/3] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.917 total time=   0.9s
# [CV 3/3] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=0.916 total time=   0.5s
# [CV 1/3] END C=1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.922 total time=   0.7s
# [CV 2/3] END C=1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.917 total time=   1.3s
# [CV 3/3] END C=1, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.916 total time=   0.5s
# [CV 1/3] END C=1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.922 total time=   0.6s
# [CV 2/3] END C=1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.917 total time=   1.0s
# [CV 3/3] END C=1, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.916 total time=   0.4s
# [CV 1/3] END C=1, class_weight=balanced, gamma=1, kernel=linear;, score=0.922 total time=   0.6s
# [CV 2/3] END C=1, class_weight=balanced, gamma=1, kernel=linear;, score=0.917 total time=   1.0s
# [CV 3/3] END C=1, class_weight=balanced, gamma=1, kernel=linear;, score=0.916 total time=   0.5s
# [CV 1/3] END C=10, class_weight=None, gamma=scale, kernel=linear;, score=0.918 total time=   5.3s
# [CV 2/3] END C=10, class_weight=None, gamma=scale, kernel=linear;, score=0.923 total time=  11.4s
# [CV 3/3] END C=10, class_weight=None, gamma=scale, kernel=linear;, score=0.926 total time=   9.2s
# [CV 1/3] END C=10, class_weight=None, gamma=0.001, kernel=linear;, score=0.918 total time=   5.6s
# [CV 2/3] END C=10, class_weight=None, gamma=0.001, kernel=linear;, score=0.923 total time=  13.5s
# [CV 3/3] END C=10, class_weight=None, gamma=0.001, kernel=linear;, score=0.926 total time=  11.0s
# [CV 1/3] END C=10, class_weight=None, gamma=0.1, kernel=linear;, score=0.918 total time=   4.8s
# [CV 2/3] END C=10, class_weight=None, gamma=0.1, kernel=linear;, score=0.923 total time=  12.4s
# [CV 3/3] END C=10, class_weight=None, gamma=0.1, kernel=linear;, score=0.926 total time=   9.8s
# [CV 1/3] END C=10, class_weight=None, gamma=1, kernel=linear;, score=0.918 total time=   6.0s
# [CV 2/3] END C=10, class_weight=None, gamma=1, kernel=linear;, score=0.923 total time=  14.2s
# [CV 3/3] END C=10, class_weight=None, gamma=1, kernel=linear;, score=0.926 total time=  11.4s
# [CV 1/3] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=0.919 total time=   6.3s
# [CV 2/3] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=0.914 total time=   6.5s
# [CV 3/3] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=0.911 total time=   9.3s
# [CV 1/3] END C=10, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.919 total time=   5.7s
# [CV 2/3] END C=10, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.914 total time=   6.2s
# [CV 3/3] END C=10, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.911 total time=   7.2s
# [CV 1/3] END C=10, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.919 total time=   6.7s
# [CV 2/3] END C=10, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.914 total time=   6.4s
# [CV 3/3] END C=10, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.911 total time=   9.2s
# [CV 1/3] END C=10, class_weight=balanced, gamma=1, kernel=linear;, score=0.919 total time=   6.3s
# [CV 2/3] END C=10, class_weight=balanced, gamma=1, kernel=linear;, score=0.914 total time=   5.5s
# [CV 3/3] END C=10, class_weight=balanced, gamma=1, kernel=linear;, score=0.911 total time=   8.7s
# [CV 1/3] END C=50, class_weight=None, gamma=scale, kernel=linear;, score=0.919 total time=  28.8s
# [CV 2/3] END C=50, class_weight=None, gamma=scale, kernel=linear;, score=0.921 total time=  36.7s
# [CV 3/3] END C=50, class_weight=None, gamma=scale, kernel=linear;, score=0.921 total time= 1.0min
# [CV 1/3] END C=50, class_weight=None, gamma=0.001, kernel=linear;, score=0.919 total time=  31.4s
# [CV 2/3] END C=50, class_weight=None, gamma=0.001, kernel=linear;, score=0.921 total time=  38.0s
# [CV 3/3] END C=50, class_weight=None, gamma=0.001, kernel=linear;, score=0.921 total time= 1.0min
# [CV 1/3] END C=50, class_weight=None, gamma=0.1, kernel=linear;, score=0.919 total time=  37.0s
# [CV 2/3] END C=50, class_weight=None, gamma=0.1, kernel=linear;, score=0.921 total time=  38.1s
# [CV 3/3] END C=50, class_weight=None, gamma=0.1, kernel=linear;, score=0.921 total time=  36.6s
# [CV 1/3] END C=50, class_weight=None, gamma=1, kernel=linear;, score=0.919 total time=  34.8s
# [CV 2/3] END C=50, class_weight=None, gamma=1, kernel=linear;, score=0.921 total time=  37.5s
# [CV 3/3] END C=50, class_weight=None, gamma=1, kernel=linear;, score=0.921 total time= 1.0min
# [CV 1/3] END C=50, class_weight=balanced, gamma=scale, kernel=linear;, score=0.917 total time=  20.3s
# [CV 2/3] END C=50, class_weight=balanced, gamma=scale, kernel=linear;, score=0.911 total time=  30.5s
# [CV 3/3] END C=50, class_weight=balanced, gamma=scale, kernel=linear;, score=0.912 total time=  19.4s
# [CV 1/3] END C=50, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.917 total time=  11.9s
# [CV 2/3] END C=50, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.911 total time=  35.1s
# [CV 3/3] END C=50, class_weight=balanced, gamma=0.001, kernel=linear;, score=0.912 total time=  34.9s
# [CV 1/3] END C=50, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.917 total time=  23.5s
# [CV 2/3] END C=50, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.911 total time=  45.4s
# [CV 3/3] END C=50, class_weight=balanced, gamma=0.1, kernel=linear;, score=0.912 total time=  32.8s
# [CV 1/3] END C=50, class_weight=balanced, gamma=1, kernel=linear;, score=0.917 total time=  26.3s
# [CV 2/3] END C=50, class_weight=balanced, gamma=1, kernel=linear;, score=0.911 total time=  50.5s
# [CV 3/3] END C=50, class_weight=balanced, gamma=1, kernel=linear;, score=0.912 total time=  49.1s
# Meilleurs hyperparamèetres:
#      C class_weight  gamma  kernel
# 0  0.1         None  scale  linear
#
# Meilleur score: 0.9282236041300876

# %%
svc_acc = {}
svc_f1 = {}

# %% [markdown]
# Meilleur modèle SVC:

# %%
svcClassifier_optimized = SVC(**best_parameters, random_state=42)

# %% [markdown]
# ## Simplified + One hot

# %%
svcClassifier_optimized.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_simplified_oneHot, y_test_simplified_oneHot)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_simplified_oneHot)
svcClassifier_optimized_f1 = f1_score(y_test_simplified_oneHot, svcClassifier_optimized_predz, average='binary')

svc_acc["Simplified + OneHot"] = svcClassifier_optimized_acc
svc_f1["Simplified + OneHot"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Original + One hot

# %%
svcClassifier_optimized.fit(X_train_original_oneHot, y_train_original_oneHot)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_original_oneHot, y_test_original_oneHot)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_original_oneHot)
svcClassifier_optimized_f1 = f1_score(y_test_original_oneHot, svcClassifier_optimized_predz, average='binary')

svc_acc["Original + OneHot"] = svcClassifier_optimized_acc
svc_f1["Original + OneHot"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Simplified

# %%
svcClassifier_optimized.fit(X_train_simplified, y_train_simplified)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_simplified, y_test_simplified)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_simplified)
svcClassifier_optimized_f1 = f1_score(y_test_simplified, svcClassifier_optimized_predz, average='binary')

svc_acc["Simplified"] = svcClassifier_optimized_acc
svc_f1["Simplified"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
svcClassifier_optimized.fit(X_train_original, y_train_original)
svcClassifier_optimized_acc = svcClassifier_optimized.score(X_test_original, y_test_original)
svcClassifier_optimized_predz = svcClassifier_optimized.predict(X_test_original)
svcClassifier_optimized_f1 = f1_score(y_test_original, svcClassifier_optimized_predz, average='binary')

svc_acc["Original"] = svcClassifier_optimized_acc
svc_f1["Original"] = svcClassifier_optimized_f1

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["SVC"] = svc_acc
dict_f1["SVC"] = svc_f1

# %% [markdown]
# # KNN

# %% [markdown]
# ## Recherche en grille

# %% [markdown]
# Le modèle par KNN n'accèpte pas d'argument random_state pour gérer la consistense du modèle.

# %%
n_range = 30
mean_acc = np.zeros(n_range)
for i in range(1,n_range + 1):
    #Train Model and Predict
    knn = KNeighborsClassifier(n_neighbors = i).fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
    yhat= knn.predict(X_test_simplified_oneHot)
    mean_acc[i-1] = metrics.accuracy_score(y_test_simplified_oneHot, yhat)
k_range_cnt = 10
k_range = np.argpartition(mean_acc, -k_range_cnt)[-k_range_cnt:]

# by default knn
knnClassifier = KNeighborsClassifier()

param_grid = {
               'n_neighbors' : k_range,
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan'],
               'algorithm' : ['ball_tree', 'kd_tree', 'brute'],
               'p' : [1,2],
}

# init grid search
grid_search = GridSearchCV(estimator=knnClassifier, param_grid=param_grid, cv=3, scoring='f1', verbose=3)

grid_search.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.885 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.888 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.900 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.896 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.880 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.885 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.890 total time=   0.6s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.895 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.899 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.881 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=distance;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=distance;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=25, p=2, weights=distance;, score=0.882 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=uniform;, score=0.891 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=uniform;, score=0.889 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=uniform;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=distance;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=23, p=2, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=0.903 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=uniform;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=19, p=2, weights=distance;, score=0.887 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=uniform;, score=0.906 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=uniform;, score=0.898 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=uniform;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=uniform;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=11, p=2, weights=distance;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=uniform;, score=0.906 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=uniform;, score=0.890 total time=   0.6s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=distance;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=uniform;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=distance;, score=0.896 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=17, p=2, weights=distance;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=uniform;, score=0.896 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=uniform;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=uniform;, score=0.894 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=distance;, score=0.898 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=uniform;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=9, p=2, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=uniform;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=uniform;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=uniform;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=distance;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=13, p=2, weights=distance;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=uniform;, score=0.890 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=distance;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=distance;, score=0.894 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=minkowski, n_neighbors=29, p=2, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=uniform;, score=0.893 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=uniform;, score=0.900 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=uniform;, score=0.884 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=distance;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=1, weights=distance;, score=0.885 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=uniform;, score=0.893 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=uniform;, score=0.900 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=uniform;, score=0.884 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=distance;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=21, p=2, weights=distance;, score=0.885 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=uniform;, score=0.896 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=uniform;, score=0.899 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=uniform;, score=0.880 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=1, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=uniform;, score=0.896 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=uniform;, score=0.899 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=uniform;, score=0.880 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=18, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=uniform;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=uniform;, score=0.881 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=distance;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=1, weights=distance;, score=0.882 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=uniform;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=uniform;, score=0.881 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=distance;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=25, p=2, weights=distance;, score=0.882 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=uniform;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=distance;, score=0.901 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=1, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=uniform;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=distance;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=23, p=2, weights=distance;, score=0.883 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=0.891 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=distance;, score=0.896 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=1, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=uniform;, score=0.891 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=uniform;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=distance;, score=0.896 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=19, p=2, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=uniform;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=uniform;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=1, weights=distance;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=uniform;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=uniform;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=11, p=2, weights=distance;, score=0.886 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=uniform;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=1, weights=distance;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=uniform;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=uniform;, score=0.884 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=17, p=2, weights=distance;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=uniform;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=1, weights=distance;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=uniform;, score=0.883 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=9, p=2, weights=distance;, score=0.883 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=uniform;, score=0.901 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=uniform;, score=0.886 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=distance;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=1, weights=distance;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=uniform;, score=0.901 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=uniform;, score=0.886 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.901 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.886 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.891 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.894 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.887 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.885 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.888 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.885 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.898 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.888 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.895 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.892 total time=   0.6s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.892 total time=   0.6s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.895 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.891 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.889 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.889 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.903 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.889 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.903 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.892 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.906 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.898 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.906 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.898 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.894 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.906 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.897 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.892 total time=   0.6s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.906 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.892 total time=   0.6s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.906 total time=   0.6s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.890 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.896 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.894 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.898 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.896 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.894 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.898 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.891 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.890 total time=   0.4s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.889 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.6s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.890 total time=   0.5s
# [CV 1/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=ball_tree, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.889 total time=   0.5s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.885 total time=   0.7s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.6s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.7s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.888 total time=   0.7s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.6s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.6s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.893 total time=   0.5s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.900 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=uniform;, score=0.884 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=21, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=uniform;, score=0.895 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.893 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.896 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=uniform;, score=0.880 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.899 total time=   0.3s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=18, p=2, weights=distance;, score=0.885 total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.890 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.893 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=uniform;, score=0.891 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.4s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=1, weights=distance;, score=0.891 total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=kd_tree, metric=minkowski, n_neighbors=25, p=2, weights=uniform;, score=0.899 total time=   0.3s
# ...
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=13, p=2, weights=distance;, score=0.886 total time=   0.0s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.892 total time=   0.1s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.891 total time=   0.1s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.1s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.892 total time=   0.1s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.894 total time=   0.0s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=1, weights=distance;, score=0.887 total time=   0.0s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.892 total time=   0.1s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.891 total time=   0.1s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.1s
# [CV 1/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.892 total time=   0.0s
# [CV 2/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.894 total time=   0.1s
# [CV 3/3] END algorithm=brute, metric=euclidean, n_neighbors=29, p=2, weights=distance;, score=0.887 total time=   0.0s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.886 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=uniform;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.886 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.898 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=uniform;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.902 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=21, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.905 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.893 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.905 total time=   0.8s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=uniform;, score=0.892 total time=   0.6s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.894 total time=   0.7s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.907 total time=   0.5s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=18, p=2, weights=distance;, score=0.895 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.891 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.894 total time=   0.7s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=uniform;, score=0.892 total time=   0.6s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.890 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.897 total time=   0.4s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=1, weights=distance;, score=0.892 total time=   0.5s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.894 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.897 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=25, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=uniform;, score=0.888 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=1, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.891 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.893 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=uniform;, score=0.888 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.896 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=23, p=2, weights=distance;, score=0.889 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.904 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=1, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.889 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.904 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=uniform;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.906 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=19, p=2, weights=distance;, score=0.892 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.893 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.905 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=uniform;, score=0.899 total time=   0.4s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.894 total time=   0.4s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.906 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=1, weights=distance;, score=0.898 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.893 total time=   0.8s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.905 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=0.899 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.894 total time=   0.5s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.906 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=11, p=2, weights=distance;, score=0.898 total time=   0.6s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.892 total time=   0.6s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.905 total time=   0.5s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=uniform;, score=0.890 total time=   0.4s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=1, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.892 total time=   0.4s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.905 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=uniform;, score=0.890 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=17, p=2, weights=distance;, score=0.891 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=uniform;, score=0.894 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.897 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=uniform;, score=0.894 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.897 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.908 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=9, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=1, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.890 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.907 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=uniform;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.894 total time=   0.3s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.910 total time=   0.3s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=13, p=2, weights=distance;, score=0.895 total time=   0.3s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.887 total time=   0.4s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.893 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=uniform;, score=0.890 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.890 total time=   0.4s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.897 total time=   0.7s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=1, weights=distance;, score=0.889 total time=   0.6s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.887 total time=   0.7s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.893 total time=   0.6s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=uniform;, score=0.890 total time=   0.7s
# [CV 1/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.890 total time=   0.5s
# [CV 2/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.897 total time=   0.5s
# [CV 3/3] END algorithm=brute, metric=manhattan, n_neighbors=29, p=2, weights=distance;, score=0.889 total time=   0.4s
# Meilleurs hyperparamèetres:
#   algorithm     metric  n_neighbors  p   weights
# 0     brute  minkowski            9  1  distance
#
# Meilleur score: 0.9001954018453863

# %%
knn_acc = {}
knn_f1 = {}

# %% [markdown]
# Meilleur modèle KNN:

# %%
knnClassifier_optimized = KNeighborsClassifier(**best_parameters)

# %% [markdown]
# ## Simplified + One hot

# %%
knnClassifier_optimized.fit(X_train_simplified_oneHot, y_train_simplified_oneHot)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_simplified_oneHot, y_test_simplified_oneHot)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_simplified_oneHot)
knnClassifier_optimized_f1 = f1_score(y_test_simplified_oneHot, knnClassifier_optimized_predz, average='binary')

knn_acc["Simplified + OneHot"] = knnClassifier_optimized_acc
knn_f1["Simplified + OneHot"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Original + One hot

# %%
knnClassifier_optimized.fit(X_train_original_oneHot, y_train_original_oneHot)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_original_oneHot, y_test_original_oneHot)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_original_oneHot)
knnClassifier_optimized_f1 = f1_score(y_test_original_oneHot, knnClassifier_optimized_predz, average='binary')

knn_acc["Original + OneHot"] = knnClassifier_optimized_acc
knn_f1["Original + OneHot"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Simplified

# %%
knnClassifier_optimized.fit(X_train_simplified, y_train_simplified)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_simplified, y_test_simplified)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_simplified)
knnClassifier_optimized_f1 = f1_score(y_test_simplified, knnClassifier_optimized_predz, average='binary')

knn_acc["Simplified"] = knnClassifier_optimized_acc
knn_f1["Simplified"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
knnClassifier_optimized.fit(X_train_original, y_train_original)
knnClassifier_optimized_acc = knnClassifier_optimized.score(X_test_original, y_test_original)
knnClassifier_optimized_predz = knnClassifier_optimized.predict(X_test_original)
knnClassifier_optimized_f1 = f1_score(y_test_original, knnClassifier_optimized_predz, average='binary')

knn_acc["Original"] = knnClassifier_optimized_acc
knn_f1["Original"] = knnClassifier_optimized_f1

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["KNN"] = knn_acc
dict_f1["KNN"] = knn_f1

# %% [markdown]
# # CatBoost

# %% [markdown]
# ## Recherche en grille

# %%
# Create a CatBoostClassifier
catboost_model = CatBoostClassifier(cat_features=cat_features_catb, verbose=0, random_state=42)

# Define the parameter grid to search
''' param_grid = {
    'iterations': [None, 100, 200, 300],
    'learning_rate': [None, 0.01, 0.05, 0.1],
    'depth': [None, 4, 6, 8],
    'l2_leaf_reg': [None, 1, 3, 5],
} '''
param_grid = {
    'iterations': [1000],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 9],
    'l2_leaf_reg': [1, 3, 5],
    'one_hot_max_size': [2, 150]
}

# init grid search
grid_search = GridSearchCV(estimator=catboost_model, param_grid=param_grid, scoring='f1', cv=3, n_jobs=1, verbose=3)

grid_search.fit(X_train_simplified, y_train_simplified)

best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print("Meilleurs hyperparamèetres:")
best_parameters_df = {key: [value] for key, value in best_parameters.items()}
df = pd.DataFrame(best_parameters_df)
print(df)
print()
print("Meilleur score:", best_score)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.925 total time=  11.3s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.933 total time=   5.1s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.919 total time=   7.4s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.924 total time=   2.8s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.931 total time=   1.6s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.914 total time=   1.5s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.921 total time=   5.3s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.934 total time=   8.8s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.916 total time=   5.4s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.918 total time=   1.5s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.927 total time=   1.5s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.917 total time=   1.8s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.918 total time=   8.6s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.933 total time=   5.4s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.915 total time=   7.4s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.922 total time=   2.8s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.927 total time=   1.6s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.921 total time=   1.5s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.921 total time=   5.0s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.933 total time=   7.8s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.919 total time=   5.9s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.922 total time=   1.5s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.930 total time=   1.9s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.916 total time=   1.6s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.919 total time=   9.1s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.933 total time=   5.2s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.915 total time=   6.9s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.918 total time=   3.0s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.927 total time=   1.9s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.919 total time=   1.5s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.917 total time=   5.3s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.932 total time=   8.3s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.921 total time=   6.0s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.916 total time=   1.5s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.927 total time=   1.5s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.921 total time=   1.6s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.926 total time=   8.7s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.932 total time=   5.4s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.918 total time=   7.4s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.924 total time=   3.1s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.932 total time=   1.8s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.915 total time=   1.6s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.925 total time=   5.3s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.937 total time=   8.6s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.919 total time=   5.5s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.918 total time=   1.6s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.930 total time=   1.5s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.922 total time=   1.9s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.915 total time=   9.1s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.938 total time=   5.3s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.917 total time=   7.5s
# [CV 1/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.922 total time=   3.0s
# [CV 2/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.922 total time=   1.6s
# [CV 3/3] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.920 total time=   1.6s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.926 total time=  10.6s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.935 total time=  10.5s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.922 total time=  12.4s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.926 total time=   2.5s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.933 total time=   2.4s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.920 total time=   2.5s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.924 total time=  12.8s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.938 total time=  12.6s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.922 total time=   9.1s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.923 total time=   4.9s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.932 total time=   4.0s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.920 total time=   2.5s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.916 total time=  11.6s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.934 total time=  10.3s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.916 total time=  12.6s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.918 total time=   2.5s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.929 total time=   2.4s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.916 total time=   2.9s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.925 total time=  11.9s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.938 total time=  12.3s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.918 total time=   8.9s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.928 total time=   4.4s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.937 total time=   4.3s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.918 total time=   2.5s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.917 total time=  11.6s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.934 total time=  10.2s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.915 total time=  12.8s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.922 total time=   2.5s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.932 total time=   2.4s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.920 total time=   3.7s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.917 total time=  11.5s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.937 total time=  12.6s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.920 total time=   9.9s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.921 total time=   4.9s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.932 total time=   2.9s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.919 total time=   2.6s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.925 total time=  11.3s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.933 total time=   9.4s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.918 total time=  12.2s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.925 total time=   2.5s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.934 total time=   2.4s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.921 total time=   2.6s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.924 total time=  12.2s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.938 total time=  12.3s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.912 total time=   9.0s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.922 total time=   4.2s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.933 total time=   4.4s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.921 total time=   2.5s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.920 total time=  10.6s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.934 total time=  10.6s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.917 total time=  12.4s
# [CV 1/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.922 total time=   2.5s
# [CV 2/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.927 total time=   2.3s
# [CV 3/3] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.918 total time=   2.5s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.928 total time=  47.4s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.931 total time=  47.4s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=2;, score=0.917 total time=  44.7s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.927 total time=  11.8s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.934 total time=  11.6s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, one_hot_max_size=150;, score=0.918 total time=   9.3s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.922 total time=  49.9s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.931 total time=  49.0s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=2;, score=0.915 total time=  48.1s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.920 total time=  10.0s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.937 total time=  10.5s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, one_hot_max_size=150;, score=0.918 total time=  12.2s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.928 total time=  46.1s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.934 total time=  47.0s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=2;, score=0.915 total time=  48.4s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.921 total time=  11.9s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.935 total time=   8.3s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, one_hot_max_size=150;, score=0.914 total time=  12.2s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.924 total time=  45.1s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.936 total time=  44.7s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=2;, score=0.920 total time=  47.9s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.925 total time=  12.1s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.934 total time=   9.5s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, one_hot_max_size=150;, score=0.920 total time=  13.0s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.927 total time=  49.9s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.931 total time=  48.8s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=2;, score=0.915 total time=  46.0s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.925 total time=  12.0s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.933 total time=  11.1s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, one_hot_max_size=150;, score=0.916 total time=   9.5s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.925 total time=  49.2s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.933 total time=  48.5s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=2;, score=0.915 total time=  47.3s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.919 total time=   9.0s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.928 total time=  11.3s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, one_hot_max_size=150;, score=0.916 total time=  10.8s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.929 total time=  43.8s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.935 total time=  45.4s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=2;, score=0.917 total time=  42.9s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.926 total time=  12.1s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.936 total time=   9.8s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, one_hot_max_size=150;, score=0.921 total time=  10.5s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.925 total time=  47.6s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.933 total time=  47.7s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=2;, score=0.918 total time=  45.5s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.922 total time=  11.4s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.931 total time=  10.8s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, one_hot_max_size=150;, score=0.918 total time=   9.3s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.929 total time=  48.7s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.932 total time=  48.3s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=2;, score=0.915 total time=  47.1s
# [CV 1/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.923 total time=   9.4s
# [CV 2/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.932 total time=  11.4s
# [CV 3/3] END depth=9, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, one_hot_max_size=150;, score=0.920 total time=  10.1s
# Meilleurs hyperparamèetres:
#    depth  iterations  l2_leaf_reg  learning_rate  one_hot_max_size
# 0      6        1000            1           0.05                 2
#
# Meilleur score: 0.9277694422620723

# %%
catb_acc = {}
catb_f1 = {}

# %% [markdown]
# Meilleur modèle CatB:

# %%
catbClassifier_optimized = grid_search.best_estimator_

# %% [markdown]
# ## Simplified + One hot

# %%
catb_acc["Simplified + OneHot"] =  None
catb_f1["Simplified + OneHot"] = None

# %% [markdown]
# ## Original + One hot

# %%
catb_acc["Original + OneHot"] = None
catb_f1["Original + OneHot"] = None

# %% [markdown]
# ## Simplified

# %%
catbClassifier_optimized.fit(X_train_simplified, y_train_simplified)
catbClassifier_optimized_acc = catbClassifier_optimized.score(X_test_simplified, y_test_simplified)
catbClassifier_optimized_predz = catbClassifier_optimized.predict(X_test_simplified)
catbClassifier_optimized_f1 = f1_score(y_test_simplified, catbClassifier_optimized_predz, average='binary')

catb_acc["Simplified"] = catbClassifier_optimized_acc
catb_f1["Simplified"] = catbClassifier_optimized_f1

# %% [markdown]
# ## Original

# %%
catb_acc["Original"] = None
catb_f1["Original"] = None

# %% [markdown]
# ## Aggrégation

# %%
dict_accuracy["CatBoost"] = catb_acc
dict_f1["CatBoost"] = catb_f1

# %% [markdown]
# # Résultats

# %%
df_acc = pd.DataFrame(dict_accuracy)
df_acc
# Out:
#                       XGboost       SVC       KNN  CatBoost
# Simplified + OneHot  0.903581  0.916437  0.878788       NaN
# Original + OneHot    0.898990  0.912764  0.877870       NaN
# Simplified           0.912764  0.915519  0.864096  0.908173
# Original             0.915519  0.918274  0.845730       NaN

# %%
df_f1 = pd.DataFrame(dict_f1)
df_f1
# Out:
#                       XGboost       SVC       KNN  CatBoost
# Simplified + OneHot  0.924731  0.934954  0.908966       NaN
# Original + OneHot    0.921764  0.932288  0.908591       NaN
# Simplified           0.932288  0.934566  0.899183  0.928367
# Original             0.934003  0.936745  0.886792       NaN
